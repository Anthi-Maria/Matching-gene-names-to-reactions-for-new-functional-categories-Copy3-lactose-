# %%
import numpy as np
import pandas as pd
import cobra.test
import os
from os.path import join

from time import time

a= cobra.io.read_sbml_model("iEC1344_C.xml")
# Out:
# Academic license - for non-commercial use only - expires 2023-02-21
# Using license file /home/schwartzlab/gurobi.lic

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7f4531a0f850>,
#             <Reaction 12PPDStex at 0x7f4531a0fd30>,
#             <Reaction 23CAMPtex at 0x7f453199c910>,
#             <Reaction 23CCMPtex at 0x7f453199ceb0>,
#             <Reaction 23CGMPtex at 0x7f453199cca0>,
#             <Reaction 23CUMPtex at 0x7f453199cf10>,
#             <Reaction 23DAPPAtex at 0x7f453199c790>,
#             <Reaction 26DAHtex at 0x7f45319b5e50>,
#             <Reaction 34dhpactex at 0x7f453191eac0>,
#             <Reaction 3AMPtex at 0x7f453191ecd0>,
#             <Reaction 3CMPtex at 0x7f4531993430>,
#             <Reaction 3GMPtex at 0x7f4531927f10>,
#             <Reaction 3HPPtex at 0x7f45319558e0>,
#             <Reaction 3PEPTtex at 0x7f45318c7eb0>,
#             <Reaction 3UMPtex at 0x7f45318daf40>,
#             <Reaction 3hoxpactex at 0x7f45168c8c10>,
#             <Reaction 4HOXPACDtex at 0x7f45318daeb0>,
#             <Reaction 4PEPTtex at 0x7f453186ebe0>,
#             <Reaction 4hoxpactex at 0x7f45168c8670>,
#             <Reaction 5DGLCNtex at 0x7f45318da610>,
#             <Reaction 5MTRtex at 0x7f4531884e50>,
#             <Reaction 6APAt1 at 0x7f451685cb80>,
#             <Reaction ABUTtex at 0x7f45318ea2b0>,
#             <Reaction ACACtex at 0x7f4531915ee0>,
#             <Reaction ACALDtex at 0x7f45318a1190>,
#             <Reaction ACGAL1Ptex at 0x7f45318c7df0>,
#             <Reaction ACGALtex at 0x7f45318c7bb0>,
#             <Reaction ACGAM1Ptex at 0x7f45318b6d60>,
#             <Reaction ACGAtex at 0x7f45318c7e50>,
#             <Reaction ACMANAtex at 0x7f453186efd0>,
#             <Reaction ACMUMtex at 0x7f4531884ca0>,
#             <Reaction ACSERtex at 0x7f4531855f70>,
#             <Reaction ACtex at 0x7f45317ef730>,
#             <Reaction ADEtex at 0x7f4531817c70>,
#             <Reaction AGMtex at 0x7f4531795c40>,
#             <Reaction AKGtex at 0x7f4531855ee0>,
#             <Reaction ALAALAtex at 0x7f453183f7c0>,
#             <Reaction ALAtex at 0x7f4531817dc0>,
#             <Reaction ALLTNtex at 0x7f45317d6880>,
#             <Reaction ALLtex at 0x7f45317c2cd0>,
#             <Reaction AMPtex at 0x7f453172ee20>,
#             <Reaction ANHGMtex at 0x7f453172eb80>,
#             <Reaction ARBTtex at 0x7f45315c12e0>,
#             <Reaction ARBtex at 0x7f45314fcd90>,
#             <Reaction ARGtex at 0x7f453144dd30>,
#             <Reaction ASCBtex at 0x7f453140aa60>,
#             <Reaction ASNtex at 0x7f4531358ac0>,
#             <Reaction ASO3tex at 0x7f4531300dc0>,
#             <Reaction ASPtex at 0x7f453172ee80>,
#             <Reaction BALAtex at 0x7f45316eff40>,
#             <Reaction BTNtex at 0x7f4531703d60>,
#             <Reaction BUTSO3tex at 0x7f4531717100>,
#             <Reaction BUTtex at 0x7f45316c3af0>,
#             <Reaction CA2tex at 0x7f45316d7d60>,
#             <Reaction CD2tex at 0x7f4531697e80>,
#             <Reaction CGLYtex at 0x7f4531759af0>,
#             <Reaction CHLtex at 0x7f4531717c40>,
#             <Reaction CHTBStex at 0x7f4531717640>,
#             <Reaction CITtex at 0x7f45316c3250>,
#             <Reaction CLBtex at 0x7f45168c8a90>,
#             <Reaction CLtex at 0x7f4531682940>,
#             <Reaction CMPtex at 0x7f4531682c70>,
#             <Reaction CMtex at 0x7f4531697f70>,
#             <Reaction CO2tex at 0x7f453162deb0>,
#             <Reaction COBALT2tex at 0x7f45316979d0>,
#             <Reaction CRNDtex at 0x7f45315ece80>,
#             <Reaction CRNtex at 0x7f4531603940>,
#             <Reaction CSNtex at 0x7f4531619f40>,
#             <Reaction CU2tex at 0x7f45315c1df0>,
#             <Reaction CUtex at 0x7f45315d7f10>,
#             <Reaction CYANtex at 0x7f45315d7be0>,
#             <Reaction CYNTtex at 0x7f453156ce20>,
#             <Reaction CYSDtex at 0x7f453156c040>,
#             <Reaction CYStex at 0x7f4531596bb0>,
#             <Reaction CYTDtex at 0x7f4531542f70>,
#             <Reaction DALAtex at 0x7f4531619130>,
#             <Reaction DAMPtex at 0x7f4531619bb0>,
#             <Reaction DAPtex at 0x7f45315af9a0>,
#             <Reaction DARBtex at 0x7f4516793cd0>,
#             <Reaction DCAtex at 0x7f453156cbb0>,
#             <Reaction DCMPtex at 0x7f45315d7df0>,
#             <Reaction DDGLCNtex at 0x7f4531580e50>,
#             <Reaction DGMPtex at 0x7f4531596eb0>,
#             <Reaction DGSNtex at 0x7f4531596fd0>,
#             <Reaction DHAtex at 0x7f4531542cd0>,
#             <Reaction DIMPtex at 0x7f45314e88e0>,
#             <Reaction DINStex at 0x7f45314e8e20>,
#             <Reaction DMSOtex at 0x7f4531511f40>,
#             <Reaction DMStex at 0x7f45314a67c0>,
#             <Reaction DOPAtex at 0x7f45314a6d60>,
#             <Reaction DOXRBCNtex at 0x7f45314a6df0>,
#             <Reaction DSERtex at 0x7f45314cfe50>,
#             <Reaction DTMPtex at 0x7f45314cfc70>,
#             <Reaction DUMPtex at 0x7f4531478eb0>,
#             <Reaction D_LACtex at 0x7f4531556ac0>,
#             <Reaction ETHAtex at 0x7f4531438d90>,
#             <Reaction ETHSO3tex at 0x7f4531423f40>,
#             <Reaction ETOHtex at 0x7f4531438dc0>,
#             <Reaction F6Ptex at 0x7f453144db80>,
#             <Reaction FALDtex at 0x7f45313f3a60>,
#             <Reaction FE2tex at 0x7f45313b1d30>,
#             <Reaction FE3tex at 0x7f453132ffd0>,
#             <Reaction FORtex at 0x7f453132fd30>,
#             <Reaction FRULYStex at 0x7f4531346d30>,
#             <Reaction FRUURtex at 0x7f4531358eb0>,
#             <Reaction FRUtex at 0x7f4531358d90>,
#             <Reaction FUCtex at 0x7f4531358f70>,
#             <Reaction FUMtex at 0x7f45312ec9d0>,
#             <Reaction FUSAtex at 0x7f4531300d30>,
#             <Reaction G1Ptex at 0x7f4531315af0>,
#             <Reaction G3PCtex at 0x7f4531315df0>,
#             <Reaction G3PEtex at 0x7f45312a9d60>,
#             <Reaction G3PGtex at 0x7f45312a9bb0>,
#             <Reaction G3PItex at 0x7f45312a99a0>,
#             <Reaction G3PStex at 0x7f45312bda90>,
#             <Reaction G6Ptex at 0x7f4531263d60>,
#             <Reaction GAL1Ptex at 0x7f4531263f70>,
#             <Reaction GALAMtex at 0x7f45168c8940>,
#             <Reaction GALBDtex at 0x7f4531263ee0>,
#             <Reaction GALCTNLtex at 0x7f453127af70>,
#             <Reaction GALCTNtex at 0x7f453128f850>,
#             <Reaction GALCTtex at 0x7f453128ff40>,
#             <Reaction GALTtex at 0x7f4531223fd0>,
#             <Reaction GALURtex at 0x7f4531223af0>,
#             <Reaction GALtex at 0x7f453124bbe0>,
#             <Reaction GAMAN6Ptex at 0x7f453124bd60>,
#             <Reaction GAMtex at 0x7f453124be50>,
#             <Reaction GBBTNtex at 0x7f453124b7f0>,
#             <Reaction GDPtex at 0x7f452f1faac0>,
#             <Reaction GLCNtex at 0x7f4531263e80>,
#             <Reaction GLCRtex at 0x7f45312638e0>,
#             <Reaction GLCUR1Ptex at 0x7f453128fdf0>,
#             <Reaction GLCURtex at 0x7f453128fdc0>,
#             <Reaction GLCtex_copy1 at 0x7f4531223820>,
#             <Reaction GLNtex at 0x7f453128feb0>,
#             <Reaction GLUtex at 0x7f452f1fad00>,
#             <Reaction GLYALDtex at 0x7f452f1fa9d0>,
#             <Reaction GLYBtex at 0x7f452f18fd90>,
#             <Reaction GLYC2Ptex at 0x7f452f1a5e80>,
#             <Reaction GLYC3Ptex at 0x7f452f1faeb0>,
#             <Reaction GLYCAtex at 0x7f45312349a0>,
#             <Reaction GLYCLTtex at 0x7f452f1622b0>,
#             <Reaction GLYCtex at 0x7f452f0dbc70>,
#             <Reaction GLYtex at 0x7f45319abf70>,
#             <Reaction GMPtex at 0x7f452efb01c0>,
#             <Reaction GSNtex at 0x7f452ee86e20>,
#             <Reaction GTHOXtex at 0x7f452ee43b50>,
#             <Reaction GTHRDtex at 0x7f452edc1c10>,
#             <Reaction GTPtex at 0x7f452ed2ea00>,
#             <Reaction H2O2tex at 0x7f452f1a5820>,
#             <Reaction H2Otex at 0x7f452f1a5430>,
#             <Reaction H2Stex at 0x7f45312a9100>,
#             <Reaction H2tex at 0x7f452f1b8e20>,
#             <Reaction HCINNMtex at 0x7f452f185760>,
#             <Reaction HG2tex at 0x7f452f173dc0>,
#             <Reaction HIStex at 0x7f452f0efe80>,
#             <Reaction HOMtex at 0x7f452f1029a0>,
#             <Reaction HPPPNtex at 0x7f452f102b50>,
#             <Reaction HXAtex at 0x7f452f1b8e50>,
#             <Reaction HYXNtex at 0x7f452f14b790>,
#             <Reaction Htex at 0x7f452f14be50>,
#             <Reaction IDONtex at 0x7f452f11a850>,
#             <Reaction ILEtex at 0x7f452f130ee0>,
#             <Reaction IMPtex at 0x7f452f0db910>,
#             <Reaction INDOLEtex at 0x7f452f0efc40>,
#             <Reaction INSTtex at 0x7f452f0efa00>,
#             <Reaction ISETACtex at 0x7f4531a9c9d0>,
#             <Reaction Ktex at 0x7f4531acb640>,
#             <Reaction LALADGLUtex at 0x7f4531a98a00>,
#             <Reaction LALALGLUtex at 0x7f4531a6fbb0>,
#             <Reaction LCTStex at 0x7f453199cac0>,
#             <Reaction LEUtex at 0x7f4531932070>,
#             <Reaction LIPOtex at 0x7f45318a1ee0>,
#             <Reaction LYStex at 0x7f45318b6df0>,
#             <Reaction LYXtex at 0x7f452efa3850>,
#             <Reaction L_LACtex_copy1 at 0x7f4531abeeb0>,
#             <Reaction L_LACtex_copy2 at 0x7f45168dfc40>,
#             <Reaction MALDtex at 0x7f452efb0e80>,
#             <Reaction MALtex at 0x7f452efc3d60>,
#             <Reaction MAN6Ptex at 0x7f452ef6e820>,
#             <Reaction MANGLYCtex at 0x7f452efb0880>,
#             <Reaction MANtex at 0x7f452efc3e20>,
#             <Reaction MELIBtex at 0x7f452ef3b970>,
#             <Reaction MEOHtex at 0x7f452ef3bf40>,
#             <Reaction METDtex at 0x7f452eecfdf0>,
#             <Reaction METSOX1tex at 0x7f452eee4f10>,
#             <Reaction METSOX2tex at 0x7f452eedaaf0>,
#             <Reaction METtex at 0x7f452ee8c880>,
#             <Reaction MG2tex at 0x7f452ee8cd00>,
#             <Reaction MINCYCtex at 0x7f452ef0dca0>,
#             <Reaction MMETtex at 0x7f452eeeee80>,
#             <Reaction MNLtex at 0x7f452ee8ce20>,
#             <Reaction MNtex at 0x7f452eefab50>,
#             <Reaction MOBDtex at 0x7f452ee8cf70>,
#             <Reaction MSO3tex at 0x7f452eefa730>,
#             <Reaction N2Otex at 0x7f452ee61d90>,
#             <Reaction NACtex at 0x7f452eeb7eb0>,
#             <Reaction NAtex at 0x7f452ee619a0>,
#             <Reaction NH4tex at 0x7f452ee43fa0>,
#             <Reaction NI2tex at 0x7f452ee2da30>,
#             <Reaction NMNtex at 0x7f452edeafa0>,
#             <Reaction NO2tex at 0x7f452edea6a0>,
#             <Reaction NO3tex at 0x7f452ee2de20>,
#             <Reaction NOtex at 0x7f452ee2d8e0>,
#             <Reaction O2Stex at 0x7f452ed83d30>,
#             <Reaction O2tex at 0x7f452ed2ee50>,
#             <Reaction OCTAtex at 0x7f452edc1970>,
#             <Reaction ORNtex at 0x7f452ed17eb0>,
#             <Reaction OROTtex at 0x7f452ed2e7c0>,
#             <Reaction PACALDtex at 0x7f452ed2ef70>,
#             <Reaction PACt1 at 0x7f451685ce80>,
#             <Reaction PEAMNtex at 0x7f452ecd7a90>,
#             <Reaction PENGt1 at 0x7f451685cac0>,
#             <Reaction PHEtex at 0x7f452ebd0e50>,
#             <Reaction PItex at 0x7f452ebd0430>,
#             <Reaction PNTOtex at 0x7f451689cf10>,
#             <Reaction PPALtex at 0x7f45168c8f70>,
#             <Reaction PPAtex at 0x7f451685c190>,
#             <Reaction PPPNtex at 0x7f451682fe50>,
#             <Reaction PPTtex at 0x7f4516841d00>,
#             <Reaction PROGLYtex at 0x7f452ebd0160>,
#             <Reaction PROtex at 0x7f452ebd0d60>,
#             <Reaction PSCLYStex at 0x7f452ebe7f70>,
#             <Reaction PSERtex at 0x7f452ebfaf10>,
#             <Reaction PTRCtex at 0x7f452eb4e610>,
#             <Reaction PYDAMtex at 0x7f452eb649a0>,
#             <Reaction PYDXNtex at 0x7f452eb0b7c0>,
#             <Reaction PYDXtex at 0x7f452eb0b550>,
#             <Reaction PYRtex at 0x7f452ebd0fd0>,
#             <Reaction QUIN2tex at 0x7f452ebe7e50>,
#             <Reaction R5Ptex at 0x7f452eba56a0>,
#             <Reaction RAFFtex at 0x7f451689cf70>,
#             <Reaction RIBtex at 0x7f452eb64d60>,
#             <Reaction RMNtex at 0x7f452eb64cd0>,
#             <Reaction SALCNtex at 0x7f45168c88e0>,
#             <Reaction SBTtex at 0x7f452eaf0f70>,
#             <Reaction SELtex at 0x7f452eaf0dc0>,
#             <Reaction SERtex at 0x7f452ea56b20>,
#             <Reaction SKMtex at 0x7f452ea7fee0>,
#             <Reaction SLNTtex at 0x7f452ea7fbe0>,
#             <Reaction SO2tex at 0x7f452ea14e50>,
#             <Reaction SO3tex at 0x7f452ea14a90>,
#             <Reaction SO4tex at 0x7f452ea27910>,
#             <Reaction SPMDtex at 0x7f452eb337f0>,
#             <Reaction SUCCtex at 0x7f452eb04d30>,
#             <Reaction SUCRtex at 0x7f452ea99b20>,
#             <Reaction SULFACtex at 0x7f452eaadb50>,
#             <Reaction TARTRDtex at 0x7f452ea999a0>,
#             <Reaction TARTRtex at 0x7f452ea56970>,
#             <Reaction TAURtex at 0x7f452ea56fd0>,
#             <Reaction TCYNTtex at 0x7f452ea6beb0>,
#             <Reaction THMDtex at 0x7f452ea27e80>,
#             <Reaction THMtex at 0x7f452ea3c1f0>,
#             <Reaction THRPtex at 0x7f452ea3cb50>,
#             <Reaction THRtex at 0x7f45169cfe80>,
#             <Reaction THYMtex at 0x7f45169cf7f0>,
#             <Reaction TMAOtex at 0x7f451698deb0>,
#             <Reaction TMAtex at 0x7f45169fbdf0>,
#             <Reaction TREtex at 0x7f451694ee80>,
#             <Reaction TRPtex at 0x7f45169fb220>,
#             <Reaction TSULtex at 0x7f4516960e20>,
#             <Reaction TTRCYCtex at 0x7f4516976dc0>,
#             <Reaction TUNGStex at 0x7f451690aee0>,
#             <Reaction TYMtex at 0x7f451690ae20>,
#             <Reaction TYRPtex at 0x7f451691fd30>,
#             <Reaction TYRtex at 0x7f45169cf880>,
#             <Reaction UACGAMtex at 0x7f45169e6af0>,
#             <Reaction UDPACGALtex at 0x7f45169e6a90>,
#             <Reaction UDPGALtex at 0x7f45169a1fd0>,
#             <Reaction UDPGLCURtex at 0x7f45169b2ee0>,
#             <Reaction UDPGtex at 0x7f45169b2970>,
#             <Reaction UMPtex at 0x7f451690aac0>,
#             <Reaction URAtex at 0x7f451691f070>,
#             <Reaction UREAtex at 0x7f451690a9a0>,
#             <Reaction VALtex at 0x7f4516933b80>,
#             <Reaction XANtex at 0x7f4516933a60>,
#             <Reaction XMPtex at 0x7f4516949e20>,
#             <Reaction XTSNtex at 0x7f45168df9d0>,
#             <Reaction XYLUtex at 0x7f45168dfb20>,
#             <Reaction XYLtex at 0x7f4516906af0>,
#             <Reaction Zn2tex at 0x7f45169065b0>})}

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

while i <1344:
   
    J= list()
    C= list()
    
    J.append(a.genes[i].name)
    C.append(a.genes[i].reactions)

    dictionary2 = dict(zip(J, C))
    dictionary.update(dictionary2)
    
    i=i+1

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7f4531a0f850>,
#             <Reaction 12PPDStex at 0x7f4531a0fd30>,
#             <Reaction 23CAMPtex at 0x7f453199c910>,
#             <Reaction 23CCMPtex at 0x7f453199ceb0>,
#             <Reaction 23CGMPtex at 0x7f453199cca0>,
#             <Reaction 23CUMPtex at 0x7f453199cf10>,
#             <Reaction 23DAPPAtex at 0x7f453199c790>,
#             <Reaction 26DAHtex at 0x7f45319b5e50>,
#             <Reaction 34dhpactex at 0x7f453191eac0>,
#             <Reaction 3AMPtex at 0x7f453191ecd0>,
#             <Reaction 3CMPtex at 0x7f4531993430>,
#             <Reaction 3GMPtex at 0x7f4531927f10>,
#             <Reaction 3HPPtex at 0x7f45319558e0>,
#             <Reaction 3PEPTtex at 0x7f45318c7eb0>,
#             <Reaction 3UMPtex at 0x7f45318daf40>,
#             <Reaction 3hoxpactex at 0x7f45168c8c10>,
#             <Reaction 4HOXPACDtex at 0x7f45318daeb0>,
#             <Reaction 4PEPTtex at 0x7f453186ebe0>,
#             <Reaction 4hoxpactex at 0x7f45168c8670>,
#             <Reaction 5DGLCNtex at 0x7f45318da610>,
#             <Reaction 5MTRtex at 0x7f4531884e50>,
#             <Reaction 6APAt1 at 0x7f451685cb80>,
#             <Reaction ABUTtex at 0x7f45318ea2b0>,
#             <Reaction ACACtex at 0x7f4531915ee0>,
#             <Reaction ACALDtex at 0x7f45318a1190>,
#             <Reaction ACGAL1Ptex at 0x7f45318c7df0>,
#             <Reaction ACGALtex at 0x7f45318c7bb0>,
#             <Reaction ACGAM1Ptex at 0x7f45318b6d60>,
#             <Reaction ACGAtex at 0x7f45318c7e50>,
#             <Reaction ACMANAtex at 0x7f453186efd0>,
#             <Reaction ACMUMtex at 0x7f4531884ca0>,
#             <Reaction ACSERtex at 0x7f4531855f70>,
#             <Reaction ACtex at 0x7f45317ef730>,
#             <Reaction ADEtex at 0x7f4531817c70>,
#             <Reaction AGMtex at 0x7f4531795c40>,
#             <Reaction AKGtex at 0x7f4531855ee0>,
#             <Reaction ALAALAtex at 0x7f453183f7c0>,
#             <Reaction ALAtex at 0x7f4531817dc0>,
#             <Reaction ALLTNtex at 0x7f45317d6880>,
#             <Reaction ALLtex at 0x7f45317c2cd0>,
#             <Reaction AMPtex at 0x7f453172ee20>,
#             <Reaction ANHGMtex at 0x7f453172eb80>,
#             <Reaction ARBTtex at 0x7f45315c12e0>,
#             <Reaction ARBtex at 0x7f45314fcd90>,
#             <Reaction ARGtex at 0x7f453144dd30>,
#             <Reaction ASCBtex at 0x7f453140aa60>,
#             <Reaction ASNtex at 0x7f4531358ac0>,
#             <Reaction ASO3tex at 0x7f4531300dc0>,
#             <Reaction ASPtex at 0x7f453172ee80>,
#             <Reaction BALAtex at 0x7f45316eff40>,
#             <Reaction BTNtex at 0x7f4531703d60>,
#             <Reaction BUTSO3tex at 0x7f4531717100>,
#             <Reaction BUTtex at 0x7f45316c3af0>,
#             <Reaction CA2tex at 0x7f45316d7d60>,
#             <Reaction CD2tex at 0x7f4531697e80>,
#             <Reaction CGLYtex at 0x7f4531759af0>,
#             <Reaction CHLtex at 0x7f4531717c40>,
#             <Reaction CHTBStex at 0x7f4531717640>,
#             <Reaction CITtex at 0x7f45316c3250>,
#             <Reaction CLBtex at 0x7f45168c8a90>,
#             <Reaction CLtex at 0x7f4531682940>,
#             <Reaction CMPtex at 0x7f4531682c70>,
#             <Reaction CMtex at 0x7f4531697f70>,
#             <Reaction CO2tex at 0x7f453162deb0>,
#             <Reaction COBALT2tex at 0x7f45316979d0>,
#             <Reaction CRNDtex at 0x7f45315ece80>,
#             <Reaction CRNtex at 0x7f4531603940>,
#             <Reaction CSNtex at 0x7f4531619f40>,
#             <Reaction CU2tex at 0x7f45315c1df0>,
#             <Reaction CUtex at 0x7f45315d7f10>,
#             <Reaction CYANtex at 0x7f45315d7be0>,
#             <Reaction CYNTtex at 0x7f453156ce20>,
#             <Reaction CYSDtex at 0x7f453156c040>,
#             <Reaction CYStex at 0x7f4531596bb0>,
#             <Reaction CYTDtex at 0x7f4531542f70>,
#             <Reaction DALAtex at 0x7f4531619130>,
#             <Reaction DAMPtex at 0x7f4531619bb0>,
#             <Reaction DAPtex at 0x7f45315af9a0>,
#             <Reaction DARBtex at 0x7f4516793cd0>,
#             <Reaction DCAtex at 0x7f453156cbb0>,
#             <Reaction DCMPtex at 0x7f45315d7df0>,
#             <Reaction DDGLCNtex at 0x7f4531580e50>,
#             <Reaction DGMPtex at 0x7f4531596eb0>,
#             <Reaction DGSNtex at 0x7f4531596fd0>,
#             <Reaction DHAtex at 0x7f4531542cd0>,
#             <Reaction DIMPtex at 0x7f45314e88e0>,
#             <Reaction DINStex at 0x7f45314e8e20>,
#             <Reaction DMSOtex at 0x7f4531511f40>,
#             <Reaction DMStex at 0x7f45314a67c0>,
#             <Reaction DOPAtex at 0x7f45314a6d60>,
#             <Reaction DOXRBCNtex at 0x7f45314a6df0>,
#             <Reaction DSERtex at 0x7f45314cfe50>,
#             <Reaction DTMPtex at 0x7f45314cfc70>,
#             <Reaction DUMPtex at 0x7f4531478eb0>,
#             <Reaction D_LACtex at 0x7f4531556ac0>,
#             <Reaction ETHAtex at 0x7f4531438d90>,
#             <Reaction ETHSO3tex at 0x7f4531423f40>,
#             <Reaction ETOHtex at 0x7f4531438dc0>,
#             <Reaction F6Ptex at 0x7f453144db80>,
#             <Reaction FALDtex at 0x7f45313f3a60>,
#             <Reaction FE2tex at 0x7f45313b1d30>,
#             <Reaction FE3tex at 0x7f453132ffd0>,
#             <Reaction FORtex at 0x7f453132fd30>,
#             <Reaction FRULYStex at 0x7f4531346d30>,
#             <Reaction FRUURtex at 0x7f4531358eb0>,
#             <Reaction FRUtex at 0x7f4531358d90>,
#             <Reaction FUCtex at 0x7f4531358f70>,
#             <Reaction FUMtex at 0x7f45312ec9d0>,
#             <Reaction FUSAtex at 0x7f4531300d30>,
#             <Reaction G1Ptex at 0x7f4531315af0>,
#             <Reaction G3PCtex at 0x7f4531315df0>,
#             <Reaction G3PEtex at 0x7f45312a9d60>,
#             <Reaction G3PGtex at 0x7f45312a9bb0>,
#             <Reaction G3PItex at 0x7f45312a99a0>,
#             <Reaction G3PStex at 0x7f45312bda90>,
#             <Reaction G6Ptex at 0x7f4531263d60>,
#             <Reaction GAL1Ptex at 0x7f4531263f70>,
#             <Reaction GALAMtex at 0x7f45168c8940>,
#             <Reaction GALBDtex at 0x7f4531263ee0>,
#             <Reaction GALCTNLtex at 0x7f453127af70>,
#             <Reaction GALCTNtex at 0x7f453128f850>,
#             <Reaction GALCTtex at 0x7f453128ff40>,
#             <Reaction GALTtex at 0x7f4531223fd0>,
#             <Reaction GALURtex at 0x7f4531223af0>,
#             <Reaction GALtex at 0x7f453124bbe0>,
#             <Reaction GAMAN6Ptex at 0x7f453124bd60>,
#             <Reaction GAMtex at 0x7f453124be50>,
#             <Reaction GBBTNtex at 0x7f453124b7f0>,
#             <Reaction GDPtex at 0x7f452f1faac0>,
#             <Reaction GLCNtex at 0x7f4531263e80>,
#             <Reaction GLCRtex at 0x7f45312638e0>,
#             <Reaction GLCUR1Ptex at 0x7f453128fdf0>,
#             <Reaction GLCURtex at 0x7f453128fdc0>,
#             <Reaction GLCtex_copy1 at 0x7f4531223820>,
#             <Reaction GLNtex at 0x7f453128feb0>,
#             <Reaction GLUtex at 0x7f452f1fad00>,
#             <Reaction GLYALDtex at 0x7f452f1fa9d0>,
#             <Reaction GLYBtex at 0x7f452f18fd90>,
#             <Reaction GLYC2Ptex at 0x7f452f1a5e80>,
#             <Reaction GLYC3Ptex at 0x7f452f1faeb0>,
#             <Reaction GLYCAtex at 0x7f45312349a0>,
#             <Reaction GLYCLTtex at 0x7f452f1622b0>,
#             <Reaction GLYCtex at 0x7f452f0dbc70>,
#             <Reaction GLYtex at 0x7f45319abf70>,
#             <Reaction GMPtex at 0x7f452efb01c0>,
#             <Reaction GSNtex at 0x7f452ee86e20>,
#             <Reaction GTHOXtex at 0x7f452ee43b50>,
#             <Reaction GTHRDtex at 0x7f452edc1c10>,
#             <Reaction GTPtex at 0x7f452ed2ea00>,
#             <Reaction H2O2tex at 0x7f452f1a5820>,
#             <Reaction H2Otex at 0x7f452f1a5430>,
#             <Reaction H2Stex at 0x7f45312a9100>,
#             <Reaction H2tex at 0x7f452f1b8e20>,
#             <Reaction HCINNMtex at 0x7f452f185760>,
#             <Reaction HG2tex at 0x7f452f173dc0>,
#             <Reaction HIStex at 0x7f452f0efe80>,
#             <Reaction HOMtex at 0x7f452f1029a0>,
#             <Reaction HPPPNtex at 0x7f452f102b50>,
#             <Reaction HXAtex at 0x7f452f1b8e50>,
#             <Reaction HYXNtex at 0x7f452f14b790>,
#             <Reaction Htex at 0x7f452f14be50>,
#             <Reaction IDONtex at 0x7f452f11a850>,
#             <Reaction ILEtex at 0x7f452f130ee0>,
#             <Reaction IMPtex at 0x7f452f0db910>,
#             <Reaction INDOLEtex at 0x7f452f0efc40>,
#             <Reaction INSTtex at 0x7f452f0efa00>,
#             <Reaction ISETACtex at 0x7f4531a9c9d0>,
#             <Reaction Ktex at 0x7f4531acb640>,
#             <Reaction LALADGLUtex at 0x7f4531a98a00>,
#             <Reaction LALALGLUtex at 0x7f4531a6fbb0>,
#             <Reaction LCTStex at 0x7f453199cac0>,
#             <Reaction LEUtex at 0x7f4531932070>,
#             <Reaction LIPOtex at 0x7f45318a1ee0>,
#             <Reaction LYStex at 0x7f45318b6df0>,
#             <Reaction LYXtex at 0x7f452efa3850>,
#             <Reaction L_LACtex_copy1 at 0x7f4531abeeb0>,
#             <Reaction L_LACtex_copy2 at 0x7f45168dfc40>,
#             <Reaction MALDtex at 0x7f452efb0e80>,
#             <Reaction MALtex at 0x7f452efc3d60>,
#             <Reaction MAN6Ptex at 0x7f452ef6e820>,
#             <Reaction MANGLYCtex at 0x7f452efb0880>,
#             <Reaction MANtex at 0x7f452efc3e20>,
#             <Reaction MELIBtex at 0x7f452ef3b970>,
#             <Reaction MEOHtex at 0x7f452ef3bf40>,
#             <Reaction METDtex at 0x7f452eecfdf0>,
#             <Reaction METSOX1tex at 0x7f452eee4f10>,
#             <Reaction METSOX2tex at 0x7f452eedaaf0>,
#             <Reaction METtex at 0x7f452ee8c880>,
#             <Reaction MG2tex at 0x7f452ee8cd00>,
#             <Reaction MINCYCtex at 0x7f452ef0dca0>,
#             <Reaction MMETtex at 0x7f452eeeee80>,
#             <Reaction MNLtex at 0x7f452ee8ce20>,
#             <Reaction MNtex at 0x7f452eefab50>,
#             <Reaction MOBDtex at 0x7f452ee8cf70>,
#             <Reaction MSO3tex at 0x7f452eefa730>,
#             <Reaction N2Otex at 0x7f452ee61d90>,
#             <Reaction NACtex at 0x7f452eeb7eb0>,
#             <Reaction NAtex at 0x7f452ee619a0>,
#             <Reaction NH4tex at 0x7f452ee43fa0>,
#             <Reaction NI2tex at 0x7f452ee2da30>,
#             <Reaction NMNtex at 0x7f452edeafa0>,
#             <Reaction NO2tex at 0x7f452edea6a0>,
#             <Reaction NO3tex at 0x7f452ee2de20>,
#             <Reaction NOtex at 0x7f452ee2d8e0>,
#             <Reaction O2Stex at 0x7f452ed83d30>,
#             <Reaction O2tex at 0x7f452ed2ee50>,
#             <Reaction OCTAtex at 0x7f452edc1970>,
#             <Reaction ORNtex at 0x7f452ed17eb0>,
#             <Reaction OROTtex at 0x7f452ed2e7c0>,
#             <Reaction PACALDtex at 0x7f452ed2ef70>,
#             <Reaction PACt1 at 0x7f451685ce80>,
#             <Reaction PEAMNtex at 0x7f452ecd7a90>,
#             <Reaction PENGt1 at 0x7f451685cac0>,
#             <Reaction PHEtex at 0x7f452ebd0e50>,
#             <Reaction PItex at 0x7f452ebd0430>,
#             <Reaction PNTOtex at 0x7f451689cf10>,
#             <Reaction PPALtex at 0x7f45168c8f70>,
#             <Reaction PPAtex at 0x7f451685c190>,
#             <Reaction PPPNtex at 0x7f451682fe50>,
#             <Reaction PPTtex at 0x7f4516841d00>,
#             <Reaction PROGLYtex at 0x7f452ebd0160>,
#             <Reaction PROtex at 0x7f452ebd0d60>,
#             <Reaction PSCLYStex at 0x7f452ebe7f70>,
#             <Reaction PSERtex at 0x7f452ebfaf10>,
#             <Reaction PTRCtex at 0x7f452eb4e610>,
#             <Reaction PYDAMtex at 0x7f452eb649a0>,
#             <Reaction PYDXNtex at 0x7f452eb0b7c0>,
#             <Reaction PYDXtex at 0x7f452eb0b550>,
#             <Reaction PYRtex at 0x7f452ebd0fd0>,
#             <Reaction QUIN2tex at 0x7f452ebe7e50>,
#             <Reaction R5Ptex at 0x7f452eba56a0>,
#             <Reaction RAFFtex at 0x7f451689cf70>,
#             <Reaction RIBtex at 0x7f452eb64d60>,
#             <Reaction RMNtex at 0x7f452eb64cd0>,
#             <Reaction SALCNtex at 0x7f45168c88e0>,
#             <Reaction SBTtex at 0x7f452eaf0f70>,
#             <Reaction SELtex at 0x7f452eaf0dc0>,
#             <Reaction SERtex at 0x7f452ea56b20>,
#             <Reaction SKMtex at 0x7f452ea7fee0>,
#             <Reaction SLNTtex at 0x7f452ea7fbe0>,
#             <Reaction SO2tex at 0x7f452ea14e50>,
#             <Reaction SO3tex at 0x7f452ea14a90>,
#             <Reaction SO4tex at 0x7f452ea27910>,
#             <Reaction SPMDtex at 0x7f452eb337f0>,
#             <Reaction SUCCtex at 0x7f452eb04d30>,
#             <Reaction SUCRtex at 0x7f452ea99b20>,
#             <Reaction SULFACtex at 0x7f452eaadb50>,
#             <Reaction TARTRDtex at 0x7f452ea999a0>,
#             <Reaction TARTRtex at 0x7f452ea56970>,
#             <Reaction TAURtex at 0x7f452ea56fd0>,
#             <Reaction TCYNTtex at 0x7f452ea6beb0>,
#             <Reaction THMDtex at 0x7f452ea27e80>,
#             <Reaction THMtex at 0x7f452ea3c1f0>,
#             <Reaction THRPtex at 0x7f452ea3cb50>,
#             <Reaction THRtex at 0x7f45169cfe80>,
#             <Reaction THYMtex at 0x7f45169cf7f0>,
#             <Reaction TMAOtex at 0x7f451698deb0>,
#             <Reaction TMAtex at 0x7f45169fbdf0>,
#             <Reaction TREtex at 0x7f451694ee80>,
#             <Reaction TRPtex at 0x7f45169fb220>,
#             <Reaction TSULtex at 0x7f4516960e20>,
#             <Reaction TTRCYCtex at 0x7f4516976dc0>,
#             <Reaction TUNGStex at 0x7f451690aee0>,
#             <Reaction TYMtex at 0x7f451690ae20>,
#             <Reaction TYRPtex at 0x7f451691fd30>,
#             <Reaction TYRtex at 0x7f45169cf880>,
#             <Reaction UACGAMtex at 0x7f45169e6af0>,
#             <Reaction UDPACGALtex at 0x7f45169e6a90>,
#             <Reaction UDPGALtex at 0x7f45169a1fd0>,
#             <Reaction UDPGLCURtex at 0x7f45169b2ee0>,
#             <Reaction UDPGtex at 0x7f45169b2970>,
#             <Reaction UMPtex at 0x7f451690aac0>,
#             <Reaction URAtex at 0x7f451691f070>,
#             <Reaction UREAtex at 0x7f451690a9a0>,
#             <Reaction VALtex at 0x7f4516933b80>,
#             <Reaction XANtex at 0x7f4516933a60>,
#             <Reaction XMPtex at 0x7f4516949e20>,
#             <Reaction XTSNtex at 0x7f45168df9d0>,
#             <Reaction XYLUtex at 0x7f45168dfb20>,
#             <Reaction XYLtex at 0x7f4516906af0>,
#             <Reaction Zn2tex at 0x7f45169065b0>}),
#  'YlbA': frozenset({<Reaction UGCIAMH at 0x7f451670eca0>}),
#  'OmpC': frozenset({<Reaction 12PPDRtex at 0x7f4531a0f850>,
#             <Reaction 12PPDStex at 0x7f4531a0fd30>,
#             <Reaction 23CAMPtex at 0x7f453199c910>,
#             <Reaction 23CCMPtex at 0x7f453199ceb0>,
#             <Reaction 23CGMPtex at 0x7f453199cca0>,
#             <Reaction 23CUMPtex at 0x7f453199cf10>,
#             <Reaction 23DAPPAtex at 0x7f453199c790>,
#             <Reaction 26DAHtex at 0x7f45319b5e50>,
#             <Reaction 34dhpactex at 0x7f453191eac0>,
#             <Reaction 3AMPtex at 0x7f453191ecd0>,
#             <Reaction 3CMPtex at 0x7f4531993430>,
#             <Reaction 3GMPtex at 0x7f4531927f10>,
#             <Reaction 3HPPtex at 0x7f45319558e0>,
#             <Reaction 3PEPTtex at 0x7f45318c7eb0>,
#             <Reaction 3UMPtex at 0x7f45318daf40>,
#             <Reaction 3hoxpactex at 0x7f45168c8c10>,
#             <Reaction 4HOXPACDtex at 0x7f45318daeb0>,
#             <Reaction 4PEPTtex at 0x7f453186ebe0>,
#             <Reaction 4hoxpactex at 0x7f45168c8670>,
#             <Reaction 5DGLCNtex at 0x7f45318da610>,
#             <Reaction 5MTRtex at 0x7f4531884e50>,
#             <Reaction 6APAt1 at 0x7f451685cb80>,
#             <Reaction ABUTtex at 0x7f45318ea2b0>,
#             <Reaction ACACtex at 0x7f4531915ee0>,
#             <Reaction ACALDtex at 0x7f45318a1190>,
#             <Reaction ACGAL1Ptex at 0x7f45318c7df0>,
#             <Reaction ACGALtex at 0x7f45318c7bb0>,
#             <Reaction ACGAM1Ptex at 0x7f45318b6d60>,
#             <Reaction ACGAtex at 0x7f45318c7e50>,
#             <Reaction ACMANAtex at 0x7f453186efd0>,
#             <Reaction ACMUMtex at 0x7f4531884ca0>,
#             <Reaction ACNAMtex at 0x7f4531884fd0>,
#             <Reaction ACSERtex at 0x7f4531855f70>,
#             <Reaction ACtex at 0x7f45317ef730>,
#             <Reaction ADEtex at 0x7f4531817c70>,
#             <Reaction AGMtex at 0x7f4531795c40>,
#             <Reaction AKGtex at 0x7f4531855ee0>,
#             <Reaction ALAALAtex at 0x7f453183f7c0>,
#             <Reaction ALAtex at 0x7f4531817dc0>,
#             <Reaction ALLTNtex at 0x7f45317d6880>,
#             <Reaction ALLtex at 0x7f45317c2cd0>,
#             <Reaction AMPtex at 0x7f453172ee20>,
#             <Reaction ANHGMtex at 0x7f453172eb80>,
#             <Reaction ARBTtex at 0x7f45315c12e0>,
#             <Reaction ARBtex at 0x7f45314fcd90>,
#             <Reaction ARGtex at 0x7f453144dd30>,
#             <Reaction ASCBtex at 0x7f453140aa60>,
#             <Reaction ASNtex at 0x7f4531358ac0>,
#             <Reaction ASO3tex at 0x7f4531300dc0>,
#             <Reaction ASPtex at 0x7f453172ee80>,
#             <Reaction BALAtex at 0x7f45316eff40>,
#             <Reaction BTNtex at 0x7f4531703d60>,
#             <Reaction BUTSO3tex at 0x7f4531717100>,
#             <Reaction BUTtex at 0x7f45316c3af0>,
#             <Reaction CA2tex at 0x7f45316d7d60>,
#             <Reaction CD2tex at 0x7f4531697e80>,
#             <Reaction CGLYtex at 0x7f4531759af0>,
#             <Reaction CHLtex at 0x7f4531717c40>,
#             <Reaction CHTBStex at 0x7f4531717640>,
#             <Reaction CITtex at 0x7f45316c3250>,
#             <Reaction CLBtex at 0x7f45168c8a90>,
#             <Reaction CLtex at 0x7f4531682940>,
#             <Reaction CMPtex at 0x7f4531682c70>,
#             <Reaction CMtex at 0x7f4531697f70>,
#             <Reaction CO2tex at 0x7f453162deb0>,
#             <Reaction COBALT2tex at 0x7f45316979d0>,
#             <Reaction CRNDtex at 0x7f45315ece80>,
#             <Reaction CRNtex at 0x7f4531603940>,
#             <Reaction CSNtex at 0x7f4531619f40>,
#             <Reaction CU2tex at 0x7f45315c1df0>,
#             <Reaction CUtex at 0x7f45315d7f10>,
#             <Reaction CYANtex at 0x7f45315d7be0>,
#             <Reaction CYNTtex at 0x7f453156ce20>,
#             <Reaction CYSDtex at 0x7f453156c040>,
#             <Reaction CYStex at 0x7f4531596bb0>,
#             <Reaction CYTDtex at 0x7f4531542f70>,
#             <Reaction DALAtex at 0x7f4531619130>,
#             <Reaction DAMPtex at 0x7f4531619bb0>,
#             <Reaction DAPtex at 0x7f45315af9a0>,
#             <Reaction DARBtex at 0x7f4516793cd0>,
#             <Reaction DCAtex at 0x7f453156cbb0>,
#             <Reaction DCMPtex at 0x7f45315d7df0>,
#             <Reaction DDGLCNtex at 0x7f4531580e50>,
#             <Reaction DGMPtex at 0x7f4531596eb0>,
#             <Reaction DGSNtex at 0x7f4531596fd0>,
#             <Reaction DHAtex at 0x7f4531542cd0>,
#             <Reaction DIMPtex at 0x7f45314e88e0>,
#             <Reaction DINStex at 0x7f45314e8e20>,
#             <Reaction DMSOtex at 0x7f4531511f40>,
#             <Reaction DMStex at 0x7f45314a67c0>,
#             <Reaction DOPAtex at 0x7f45314a6d60>,
#             <Reaction DOXRBCNtex at 0x7f45314a6df0>,
#             <Reaction DSERtex at 0x7f45314cfe50>,
#             <Reaction DTMPtex at 0x7f45314cfc70>,
#             <Reaction DUMPtex at 0x7f4531478eb0>,
#             <Reaction D_LACtex at 0x7f4531556ac0>,
#             <Reaction ETHAtex at 0x7f4531438d90>,
#             <Reaction ETHSO3tex at 0x7f4531423f40>,
#             <Reaction ETOHtex at 0x7f4531438dc0>,
#             <Reaction F6Ptex at 0x7f453144db80>,
#             <Reaction FALDtex at 0x7f45313f3a60>,
#             <Reaction FE2tex at 0x7f45313b1d30>,
#             <Reaction FE3tex at 0x7f453132ffd0>,
#             <Reaction FORtex at 0x7f453132fd30>,
#             <Reaction FRULYStex at 0x7f4531346d30>,
#             <Reaction FRUURtex at 0x7f4531358eb0>,
#             <Reaction FRUtex at 0x7f4531358d90>,
#             <Reaction FUCtex at 0x7f4531358f70>,
#             <Reaction FUMtex at 0x7f45312ec9d0>,
#             <Reaction FUSAtex at 0x7f4531300d30>,
#             <Reaction G1Ptex at 0x7f4531315af0>,
#             <Reaction G3PCtex at 0x7f4531315df0>,
#             <Reaction G3PEtex at 0x7f45312a9d60>,
#             <Reaction G3PGtex at 0x7f45312a9bb0>,
#             <Reaction G3PItex at 0x7f45312a99a0>,
#             <Reaction G3PStex at 0x7f45312bda90>,
#             <Reaction G6Ptex at 0x7f4531263d60>,
#             <Reaction GAL1Ptex at 0x7f4531263f70>,
#             <Reaction GALAMtex at 0x7f45168c8940>,
#             <Reaction GALBDtex at 0x7f4531263ee0>,
#             <Reaction GALCTNLtex at 0x7f453127af70>,
#             <Reaction GALCTNtex at 0x7f453128f850>,
#             <Reaction GALCTtex at 0x7f453128ff40>,
#             <Reaction GALTtex at 0x7f4531223fd0>,
#             <Reaction GALURtex at 0x7f4531223af0>,
#             <Reaction GALtex at 0x7f453124bbe0>,
#             <Reaction GAMAN6Ptex at 0x7f453124bd60>,
#             <Reaction GAMtex at 0x7f453124be50>,
#             <Reaction GBBTNtex at 0x7f453124b7f0>,
#             <Reaction GDPtex at 0x7f452f1faac0>,
#             <Reaction GLCNtex at 0x7f4531263e80>,
#             <Reaction GLCRtex at 0x7f45312638e0>,
#             <Reaction GLCUR1Ptex at 0x7f453128fdf0>,
#             <Reaction GLCURtex at 0x7f453128fdc0>,
#             <Reaction GLCtex_copy1 at 0x7f4531223820>,
#             <Reaction GLNtex at 0x7f453128feb0>,
#             <Reaction GLUtex at 0x7f452f1fad00>,
#             <Reaction GLYALDtex at 0x7f452f1fa9d0>,
#             <Reaction GLYBtex at 0x7f452f18fd90>,
#             <Reaction GLYC2Ptex at 0x7f452f1a5e80>,
#             <Reaction GLYC3Ptex at 0x7f452f1faeb0>,
#             <Reaction GLYCAtex at 0x7f45312349a0>,
#             <Reaction GLYCLTtex at 0x7f452f1622b0>,
#             <Reaction GLYCtex at 0x7f452f0dbc70>,
#             <Reaction GLYtex at 0x7f45319abf70>,
#             <Reaction GMPtex at 0x7f452efb01c0>,
#             <Reaction GSNtex at 0x7f452ee86e20>,
#             <Reaction GTHOXtex at 0x7f452ee43b50>,
#             <Reaction GTHRDtex at 0x7f452edc1c10>,
#             <Reaction GTPtex at 0x7f452ed2ea00>,
#             <Reaction H2O2tex at 0x7f452f1a5820>,
#             <Reaction H2Otex at 0x7f452f1a5430>,
#             <Reaction H2Stex at 0x7f45312a9100>,
#             <Reaction H2tex at 0x7f452f1b8e20>,
#             <Reaction HCINNMtex at 0x7f452f185760>,
#             <Reaction HG2tex at 0x7f452f173dc0>,
#             <Reaction HIStex at 0x7f452f0efe80>,
#             <Reaction HOMtex at 0x7f452f1029a0>,
#             <Reaction HPPPNtex at 0x7f452f102b50>,
#             <Reaction HXAtex at 0x7f452f1b8e50>,
#             <Reaction HYXNtex at 0x7f452f14b790>,
#             <Reaction Htex at 0x7f452f14be50>,
#             <Reaction IDONtex at 0x7f452f11a850>,
#             <Reaction ILEtex at 0x7f452f130ee0>,
#             <Reaction IMPtex at 0x7f452f0db910>,
#             <Reaction INDOLEtex at 0x7f452f0efc40>,
#             <Reaction INSTtex at 0x7f452f0efa00>,
#             <Reaction ISETACtex at 0x7f4531a9c9d0>,
#             <Reaction Ktex at 0x7f4531acb640>,
#             <Reaction LALADGLUtex at 0x7f4531a98a00>,
#             <Reaction LALALGLUtex at 0x7f4531a6fbb0>,
#             <Reaction LCTStex at 0x7f453199cac0>,
#             <Reaction LEUtex at 0x7f4531932070>,
#             <Reaction LIPOtex at 0x7f45318a1ee0>,
#             <Reaction LYStex at 0x7f45318b6df0>,
#             <Reaction LYXtex at 0x7f452efa3850>,
#             <Reaction L_LACtex_copy1 at 0x7f4531abeeb0>,
#             <Reaction L_LACtex_copy2 at 0x7f45168dfc40>,
#             <Reaction MALDtex at 0x7f452efb0e80>,
#             <Reaction MALtex at 0x7f452efc3d60>,
#             <Reaction MAN6Ptex at 0x7f452ef6e820>,
#             <Reaction MANGLYCtex at 0x7f452efb0880>,
#             <Reaction MANtex at 0x7f452efc3e20>,
#             <Reaction MELIBtex at 0x7f452ef3b970>,
#             <Reaction MEOHtex at 0x7f452ef3bf40>,
#             <Reaction METDtex at 0x7f452eecfdf0>,
#             <Reaction METSOX1tex at 0x7f452eee4f10>,
#             <Reaction METSOX2tex at 0x7f452eedaaf0>,
#             <Reaction METtex at 0x7f452ee8c880>,
#             <Reaction MG2tex at 0x7f452ee8cd00>,
#             <Reaction MINCYCtex at 0x7f452ef0dca0>,
#             <Reaction MMETtex at 0x7f452eeeee80>,
#             <Reaction MNLtex at 0x7f452ee8ce20>,
#             <Reaction MNtex at 0x7f452eefab50>,
#             <Reaction MOBDtex at 0x7f452ee8cf70>,
#             <Reaction MSO3tex at 0x7f452eefa730>,
#             <Reaction N2Otex at 0x7f452ee61d90>,
#             <Reaction NACtex at 0x7f452eeb7eb0>,
#             <Reaction NAtex at 0x7f452ee619a0>,
#             <Reaction NH4tex at 0x7f452ee43fa0>,
#             <Reaction NI2tex at 0x7f452ee2da30>,
#             <Reaction NMNtex at 0x7f452edeafa0>,
#             <Reaction NO2tex at 0x7f452edea6a0>,
#             <Reaction NO3tex at 0x7f452ee2de20>,
#             <Reaction NOtex at 0x7f452ee2d8e0>,
#             <Reaction O2Stex at 0x7f452ed83d30>,
#             <Reaction O2tex at 0x7f452ed2ee50>,
#             <Reaction OCTAtex at 0x7f452edc1970>,
#             <Reaction ORNtex at 0x7f452ed17eb0>,
#             <Reaction OROTtex at 0x7f452ed2e7c0>,
#             <Reaction PACALDtex at 0x7f452ed2ef70>,
#             <Reaction PACt1 at 0x7f451685ce80>,
#             <Reaction PEAMNtex at 0x7f452ecd7a90>,
#             <Reaction PENGt1 at 0x7f451685cac0>,
#             <Reaction PHEtex at 0x7f452ebd0e50>,
#             <Reaction PItex at 0x7f452ebd0430>,
#             <Reaction PNTOtex at 0x7f451689cf10>,
#             <Reaction PPALtex at 0x7f45168c8f70>,
#             <Reaction PPAtex at 0x7f451685c190>,
#             <Reaction PPPNtex at 0x7f451682fe50>,
#             <Reaction PPTtex at 0x7f4516841d00>,
#             <Reaction PROGLYtex at 0x7f452ebd0160>,
#             <Reaction PROtex at 0x7f452ebd0d60>,
#             <Reaction PSCLYStex at 0x7f452ebe7f70>,
#             <Reaction PSERtex at 0x7f452ebfaf10>,
#             <Reaction PTRCtex at 0x7f452eb4e610>,
#             <Reaction PYDAMtex at 0x7f452eb649a0>,
#             <Reaction PYDXNtex at 0x7f452eb0b7c0>,
#             <Reaction PYDXtex at 0x7f452eb0b550>,
#             <Reaction PYRtex at 0x7f452ebd0fd0>,
#             <Reaction QUIN2tex at 0x7f452ebe7e50>,
#             <Reaction R5Ptex at 0x7f452eba56a0>,
#             <Reaction RAFFtex at 0x7f451689cf70>,
#             <Reaction RIBtex at 0x7f452eb64d60>,
#             <Reaction RMNtex at 0x7f452eb64cd0>,
#             <Reaction SALCNtex at 0x7f45168c88e0>,
#             <Reaction SBTtex at 0x7f452eaf0f70>,
#             <Reaction SELtex at 0x7f452eaf0dc0>,
#             <Reaction SERtex at 0x7f452ea56b20>,
#             <Reaction SKMtex at 0x7f452ea7fee0>,
#             <Reaction SLNTtex at 0x7f452ea7fbe0>,
#             <Reaction SO2tex at 0x7f452ea14e50>,
#             <Reaction SO3tex at 0x7f452ea14a90>,
#             <Reaction SO4tex at 0x7f452ea27910>,
#             <Reaction SPMDtex at 0x7f452eb337f0>,
#             <Reaction SUCCtex at 0x7f452eb04d30>,
#             <Reaction SUCRtex at 0x7f452ea99b20>,
#             <Reaction SULFACtex at 0x7f452eaadb50>,
#             <Reaction TARTRDtex at 0x7f452ea999a0>,
#             <Reaction TARTRtex at 0x7f452ea56970>,
#             <Reaction TAURtex at 0x7f452ea56fd0>,
#             <Reaction TCYNTtex at 0x7f452ea6beb0>,
#             <Reaction THMDtex at 0x7f452ea27e80>,
#             <Reaction THMtex at 0x7f452ea3c1f0>,
#             <Reaction THRPtex at 0x7f452ea3cb50>,
#             <Reaction THRtex at 0x7f45169cfe80>,
#             <Reaction THYMtex at 0x7f45169cf7f0>,
#             <Reaction TMAOtex at 0x7f451698deb0>,
#             <Reaction TMAtex at 0x7f45169fbdf0>,
#             <Reaction TREtex at 0x7f451694ee80>,
#             <Reaction TRPtex at 0x7f45169fb220>,
#             <Reaction TSULtex at 0x7f4516960e20>,
#             <Reaction TTRCYCtex at 0x7f4516976dc0>,
#             <Reaction TUNGStex at 0x7f451690aee0>,
#             <Reaction TYMtex at 0x7f451690ae20>,
#             <Reaction TYRPtex at 0x7f451691fd30>,
#             <Reaction TYRtex at 0x7f45169cf880>,
#             <Reaction UACGAMtex at 0x7f45169e6af0>,
#             <Reaction UDPACGALtex at 0x7f45169e6a90>,
#             <Reaction UDPGALtex at 0x7f45169a1fd0>,
#             <Reaction UDPGLCURtex at 0x7f45169b2ee0>,
#             <Reaction UDPGtex at 0x7f45169b2970>,
#             <Reaction UMPtex at 0x7f451690aac0>,
#             <Reaction URAtex at 0x7f451691f070>,
#             <Reaction UREAtex at 0x7f451690a9a0>,
#             <Reaction VALtex at 0x7f4516933b80>,
#             <Reaction XANtex at 0x7f4516933a60>,
#             <Reaction XMPtex at 0x7f4516949e20>,
#             <Reaction XTSNtex at 0x7f45168df9d0>,
#             <Reaction XYLUtex at 0x7f45168dfb20>,
#             <Reaction XYLtex at 0x7f4516906af0>,
#             <Reaction Zn2tex at 0x7f45169065b0>}),
#  'OmpF': frozenset({<Reaction 12PPDRtex at 0x7f4531a0f850>,
#             <Reaction 12PPDStex at 0x7f4531a0fd30>,
#             <Reaction 23CAMPtex at 0x7f453199c910>,
#             <Reaction 23CCMPtex at 0x7f453199ceb0>,
#             <Reaction 23CGMPtex at 0x7f453199cca0>,
#             <Reaction 23CUMPtex at 0x7f453199cf10>,
#             <Reaction 23DAPPAtex at 0x7f453199c790>,
#             <Reaction 26DAHtex at 0x7f45319b5e50>,
#             <Reaction 34dhpactex at 0x7f453191eac0>,
#             <Reaction 3AMPtex at 0x7f453191ecd0>,
#             <Reaction 3CMPtex at 0x7f4531993430>,
#             <Reaction 3GMPtex at 0x7f4531927f10>,
#             <Reaction 3HPPtex at 0x7f45319558e0>,
#             <Reaction 3PEPTtex at 0x7f45318c7eb0>,
#             <Reaction 3UMPtex at 0x7f45318daf40>,
#             <Reaction 3hoxpactex at 0x7f45168c8c10>,
#             <Reaction 4HOXPACDtex at 0x7f45318daeb0>,
#             <Reaction 4PEPTtex at 0x7f453186ebe0>,
#             <Reaction 4hoxpactex at 0x7f45168c8670>,
#             <Reaction 5DGLCNtex at 0x7f45318da610>,
#             <Reaction 5MTRtex at 0x7f4531884e50>,
#             <Reaction 6APAt1 at 0x7f451685cb80>,
#             <Reaction ABUTtex at 0x7f45318ea2b0>,
#             <Reaction ACACtex at 0x7f4531915ee0>,
#             <Reaction ACALDtex at 0x7f45318a1190>,
#             <Reaction ACGAL1Ptex at 0x7f45318c7df0>,
#             <Reaction ACGALtex at 0x7f45318c7bb0>,
#             <Reaction ACGAM1Ptex at 0x7f45318b6d60>,
#             <Reaction ACGAtex at 0x7f45318c7e50>,
#             <Reaction ACMANAtex at 0x7f453186efd0>,
#             <Reaction ACMUMtex at 0x7f4531884ca0>,
#             <Reaction ACNAMtex at 0x7f4531884fd0>,
#             <Reaction ACSERtex at 0x7f4531855f70>,
#             <Reaction ACtex at 0x7f45317ef730>,
#             <Reaction ADEtex at 0x7f4531817c70>,
#             <Reaction AGMtex at 0x7f4531795c40>,
#             <Reaction AKGtex at 0x7f4531855ee0>,
#             <Reaction ALAALAtex at 0x7f453183f7c0>,
#             <Reaction ALAtex at 0x7f4531817dc0>,
#             <Reaction ALLTNtex at 0x7f45317d6880>,
#             <Reaction ALLtex at 0x7f45317c2cd0>,
#             <Reaction AMPtex at 0x7f453172ee20>,
#             <Reaction ANHGMtex at 0x7f453172eb80>,
#             <Reaction ARBTtex at 0x7f45315c12e0>,
#             <Reaction ARBtex at 0x7f45314fcd90>,
#             <Reaction ARGtex at 0x7f453144dd30>,
#             <Reaction ASCBtex at 0x7f453140aa60>,
#             <Reaction ASNtex at 0x7f4531358ac0>,
#             <Reaction ASO3tex at 0x7f4531300dc0>,
#             <Reaction ASPtex at 0x7f453172ee80>,
#             <Reaction BALAtex at 0x7f45316eff40>,
#             <Reaction BTNtex at 0x7f4531703d60>,
#             <Reaction BUTSO3tex at 0x7f4531717100>,
#             <Reaction BUTtex at 0x7f45316c3af0>,
#             <Reaction CA2tex at 0x7f45316d7d60>,
#             <Reaction CD2tex at 0x7f4531697e80>,
#             <Reaction CGLYtex at 0x7f4531759af0>,
#             <Reaction CHLtex at 0x7f4531717c40>,
#             <Reaction CHTBStex at 0x7f4531717640>,
#             <Reaction CITtex at 0x7f45316c3250>,
#             <Reaction CLBtex at 0x7f45168c8a90>,
#             <Reaction CLtex at 0x7f4531682940>,
#             <Reaction CMPtex at 0x7f4531682c70>,
#             <Reaction CMtex at 0x7f4531697f70>,
#             <Reaction CO2tex at 0x7f453162deb0>,
#             <Reaction COBALT2tex at 0x7f45316979d0>,
#             <Reaction CRNDtex at 0x7f45315ece80>,
#             <Reaction CRNtex at 0x7f4531603940>,
#             <Reaction CSNtex at 0x7f4531619f40>,
#             <Reaction CU2tex at 0x7f45315c1df0>,
#             <Reaction CUtex at 0x7f45315d7f10>,
#             <Reaction CYANtex at 0x7f45315d7be0>,
#             <Reaction CYNTtex at 0x7f453156ce20>,
#             <Reaction CYSDtex at 0x7f453156c040>,
#             <Reaction CYStex at 0x7f4531596bb0>,
#             <Reaction CYTDtex at 0x7f4531542f70>,
#             <Reaction DALAtex at 0x7f4531619130>,
#             <Reaction DAMPtex at 0x7f4531619bb0>,
#             <Reaction DAPtex at 0x7f45315af9a0>,
#             <Reaction DARBtex at 0x7f4516793cd0>,
#             <Reaction DCAtex at 0x7f453156cbb0>,
#             <Reaction DCMPtex at 0x7f45315d7df0>,
#             <Reaction DDGLCNtex at 0x7f4531580e50>,
#             <Reaction DGMPtex at 0x7f4531596eb0>,
#             <Reaction DGSNtex at 0x7f4531596fd0>,
#             <Reaction DHAtex at 0x7f4531542cd0>,
#             <Reaction DIMPtex at 0x7f45314e88e0>,
#             <Reaction DINStex at 0x7f45314e8e20>,
#             <Reaction DMSOtex at 0x7f4531511f40>,
#             <Reaction DMStex at 0x7f45314a67c0>,
#             <Reaction DOPAtex at 0x7f45314a6d60>,
#             <Reaction DOXRBCNtex at 0x7f45314a6df0>,
#             <Reaction DSERtex at 0x7f45314cfe50>,
#             <Reaction DTMPtex at 0x7f45314cfc70>,
#             <Reaction DUMPtex at 0x7f4531478eb0>,
#             <Reaction D_LACtex at 0x7f4531556ac0>,
#             <Reaction ETHAtex at 0x7f4531438d90>,
#             <Reaction ETHSO3tex at 0x7f4531423f40>,
#             <Reaction ETOHtex at 0x7f4531438dc0>,
#             <Reaction F6Ptex at 0x7f453144db80>,
#             <Reaction FALDtex at 0x7f45313f3a60>,
#             <Reaction FE2tex at 0x7f45313b1d30>,
#             <Reaction FE3tex at 0x7f453132ffd0>,
#             <Reaction FORtex at 0x7f453132fd30>,
#             <Reaction FRULYStex at 0x7f4531346d30>,
#             <Reaction FRUURtex at 0x7f4531358eb0>,
#             <Reaction FRUtex at 0x7f4531358d90>,
#             <Reaction FUCtex at 0x7f4531358f70>,
#             <Reaction FUMtex at 0x7f45312ec9d0>,
#             <Reaction FUSAtex at 0x7f4531300d30>,
#             <Reaction G1Ptex at 0x7f4531315af0>,
#             <Reaction G3PCtex at 0x7f4531315df0>,
#             <Reaction G3PEtex at 0x7f45312a9d60>,
#             <Reaction G3PGtex at 0x7f45312a9bb0>,
#             <Reaction G3PItex at 0x7f45312a99a0>,
#             <Reaction G3PStex at 0x7f45312bda90>,
#             <Reaction G6Ptex at 0x7f4531263d60>,
#             <Reaction GAL1Ptex at 0x7f4531263f70>,
#             <Reaction GALAMtex at 0x7f45168c8940>,
#             <Reaction GALBDtex at 0x7f4531263ee0>,
#             <Reaction GALCTNLtex at 0x7f453127af70>,
#             <Reaction GALCTNtex at 0x7f453128f850>,
#             <Reaction GALCTtex at 0x7f453128ff40>,
#             <Reaction GALTtex at 0x7f4531223fd0>,
#             <Reaction GALURtex at 0x7f4531223af0>,
#             <Reaction GALtex at 0x7f453124bbe0>,
#             <Reaction GAMAN6Ptex at 0x7f453124bd60>,
#             <Reaction GAMtex at 0x7f453124be50>,
#             <Reaction GBBTNtex at 0x7f453124b7f0>,
#             <Reaction GDPtex at 0x7f452f1faac0>,
#             <Reaction GLCNtex at 0x7f4531263e80>,
#             <Reaction GLCRtex at 0x7f45312638e0>,
#             <Reaction GLCUR1Ptex at 0x7f453128fdf0>,
#             <Reaction GLCURtex at 0x7f453128fdc0>,
#             <Reaction GLCtex_copy1 at 0x7f4531223820>,
#             <Reaction GLNtex at 0x7f453128feb0>,
#             <Reaction GLUtex at 0x7f452f1fad00>,
#             <Reaction GLYALDtex at 0x7f452f1fa9d0>,
#             <Reaction GLYBtex at 0x7f452f18fd90>,
#             <Reaction GLYC2Ptex at 0x7f452f1a5e80>,
#             <Reaction GLYC3Ptex at 0x7f452f1faeb0>,
#             <Reaction GLYCAtex at 0x7f45312349a0>,
#             <Reaction GLYCLTtex at 0x7f452f1622b0>,
#             <Reaction GLYCtex at 0x7f452f0dbc70>,
#             <Reaction GLYtex at 0x7f45319abf70>,
#             <Reaction GMPtex at 0x7f452efb01c0>,
#             <Reaction GSNtex at 0x7f452ee86e20>,
#             <Reaction GTHOXtex at 0x7f452ee43b50>,
#             <Reaction GTHRDtex at 0x7f452edc1c10>,
#             <Reaction GTPtex at 0x7f452ed2ea00>,
#             <Reaction H2O2tex at 0x7f452f1a5820>,
#             <Reaction H2Otex at 0x7f452f1a5430>,
#             <Reaction H2Stex at 0x7f45312a9100>,
#             <Reaction H2tex at 0x7f452f1b8e20>,
#             <Reaction HCINNMtex at 0x7f452f185760>,
#             <Reaction HG2tex at 0x7f452f173dc0>,
#             <Reaction HIStex at 0x7f452f0efe80>,
#             <Reaction HOMtex at 0x7f452f1029a0>,
#             <Reaction HPPPNtex at 0x7f452f102b50>,
#             <Reaction HXAtex at 0x7f452f1b8e50>,
#             <Reaction HYXNtex at 0x7f452f14b790>,
#             <Reaction Htex at 0x7f452f14be50>,
#             <Reaction IDONtex at 0x7f452f11a850>,
#             <Reaction ILEtex at 0x7f452f130ee0>,
#             <Reaction IMPtex at 0x7f452f0db910>,
#             <Reaction INDOLEtex at 0x7f452f0efc40>,
#             <Reaction INSTtex at 0x7f452f0efa00>,
#             <Reaction ISETACtex at 0x7f4531a9c9d0>,
#             <Reaction Ktex at 0x7f4531acb640>,
#             <Reaction LALADGLUtex at 0x7f4531a98a00>,
#             <Reaction LALALGLUtex at 0x7f4531a6fbb0>,
#             <Reaction LCTStex at 0x7f453199cac0>,
#             <Reaction LEUtex at 0x7f4531932070>,
#             <Reaction LIPOtex at 0x7f45318a1ee0>,
#             <Reaction LYStex at 0x7f45318b6df0>,
#             <Reaction LYXtex at 0x7f452efa3850>,
#             <Reaction L_LACtex_copy1 at 0x7f4531abeeb0>,
#             <Reaction L_LACtex_copy2 at 0x7f45168dfc40>,
#             <Reaction MALDtex at 0x7f452efb0e80>,
#             <Reaction MALtex at 0x7f452efc3d60>,
#             <Reaction MAN6Ptex at 0x7f452ef6e820>,
#             <Reaction MANGLYCtex at 0x7f452efb0880>,
#             <Reaction MANtex at 0x7f452efc3e20>,
#             <Reaction MELIBtex at 0x7f452ef3b970>,
#             <Reaction MEOHtex at 0x7f452ef3bf40>,
#             <Reaction METDtex at 0x7f452eecfdf0>,
#             <Reaction METSOX1tex at 0x7f452eee4f10>,
#             <Reaction METSOX2tex at 0x7f452eedaaf0>,
#             <Reaction METtex at 0x7f452ee8c880>,
#             <Reaction MG2tex at 0x7f452ee8cd00>,
#             <Reaction MINCYCtex at 0x7f452ef0dca0>,
#             <Reaction MMETtex at 0x7f452eeeee80>,
#             <Reaction MNLtex at 0x7f452ee8ce20>,
#             <Reaction MNtex at 0x7f452eefab50>,
#             <Reaction MOBDtex at 0x7f452ee8cf70>,
#             <Reaction MSO3tex at 0x7f452eefa730>,
#             <Reaction N2Otex at 0x7f452ee61d90>,
#             <Reaction NACtex at 0x7f452eeb7eb0>,
#             <Reaction NAtex at 0x7f452ee619a0>,
#             <Reaction NH4tex at 0x7f452ee43fa0>,
#             <Reaction NI2tex at 0x7f452ee2da30>,
#             <Reaction NMNtex at 0x7f452edeafa0>,
#             <Reaction NO2tex at 0x7f452edea6a0>,
#             <Reaction NO3tex at 0x7f452ee2de20>,
#             <Reaction NOtex at 0x7f452ee2d8e0>,
#             <Reaction O2Stex at 0x7f452ed83d30>,
#             <Reaction O2tex at 0x7f452ed2ee50>,
#             <Reaction OCTAtex at 0x7f452edc1970>,
#             <Reaction ORNtex at 0x7f452ed17eb0>,
#             <Reaction OROTtex at 0x7f452ed2e7c0>,
#             <Reaction PACALDtex at 0x7f452ed2ef70>,
#             <Reaction PACt1 at 0x7f451685ce80>,
#             <Reaction PEAMNtex at 0x7f452ecd7a90>,
#             <Reaction PENGt1 at 0x7f451685cac0>,
#             <Reaction PHEtex at 0x7f452ebd0e50>,
#             <Reaction PItex at 0x7f452ebd0430>,
#             <Reaction PNTOtex at 0x7f451689cf10>,
#             <Reaction PPALtex at 0x7f45168c8f70>,
#             <Reaction PPAtex at 0x7f451685c190>,
#             <Reaction PPPNtex at 0x7f451682fe50>,
#             <Reaction PPTtex at 0x7f4516841d00>,
#             <Reaction PROGLYtex at 0x7f452ebd0160>,
#             <Reaction PROtex at 0x7f452ebd0d60>,
#             <Reaction PSCLYStex at 0x7f452ebe7f70>,
#             <Reaction PSERtex at 0x7f452ebfaf10>,
#             <Reaction PTRCtex at 0x7f452eb4e610>,
#             <Reaction PYDAMtex at 0x7f452eb649a0>,
#             <Reaction PYDXNtex at 0x7f452eb0b7c0>,
#             <Reaction PYDXtex at 0x7f452eb0b550>,
#             <Reaction PYRtex at 0x7f452ebd0fd0>,
#             <Reaction QUIN2tex at 0x7f452ebe7e50>,
#             <Reaction R5Ptex at 0x7f452eba56a0>,
#             <Reaction RAFFtex at 0x7f451689cf70>,
#             <Reaction RIBtex at 0x7f452eb64d60>,
#             <Reaction RMNtex at 0x7f452eb64cd0>,
#             <Reaction SALCNtex at 0x7f45168c88e0>,
#             <Reaction SBTtex at 0x7f452eaf0f70>,
#             <Reaction SELtex at 0x7f452eaf0dc0>,
#             <Reaction SERtex at 0x7f452ea56b20>,
#             <Reaction SKMtex at 0x7f452ea7fee0>,
#             <Reaction SLNTtex at 0x7f452ea7fbe0>,
#             <Reaction SO2tex at 0x7f452ea14e50>,
#             <Reaction SO3tex at 0x7f452ea14a90>,
#             <Reaction SO4tex at 0x7f452ea27910>,
#             <Reaction SPMDtex at 0x7f452eb337f0>,
#             <Reaction SUCCtex at 0x7f452eb04d30>,
#             <Reaction SUCRtex at 0x7f452ea99b20>,
#             <Reaction SULFACtex at 0x7f452eaadb50>,
#             <Reaction TARTRDtex at 0x7f452ea999a0>,
#             <Reaction TARTRtex at 0x7f452ea56970>,
#             <Reaction TAURtex at 0x7f452ea56fd0>,
#             <Reaction TCYNTtex at 0x7f452ea6beb0>,
#             <Reaction THMDtex at 0x7f452ea27e80>,
#             <Reaction THMtex at 0x7f452ea3c1f0>,
#             <Reaction THRPtex at 0x7f452ea3cb50>,
#             <Reaction THRtex at 0x7f45169cfe80>,
#             <Reaction THYMtex at 0x7f45169cf7f0>,
#             <Reaction TMAOtex at 0x7f451698deb0>,
#             <Reaction TMAtex at 0x7f45169fbdf0>,
#             <Reaction TREtex at 0x7f451694ee80>,
#             <Reaction TRPtex at 0x7f45169fb220>,
#             <Reaction TSULtex at 0x7f4516960e20>,
#             <Reaction TTRCYCtex at 0x7f4516976dc0>,
#             <Reaction TUNGStex at 0x7f451690aee0>,
#             <Reaction TYMtex at 0x7f451690ae20>,
#             <Reaction TYRPtex at 0x7f451691fd30>,
#             <Reaction TYRtex at 0x7f45169cf880>,
#             <Reaction UACGAMtex at 0x7f45169e6af0>,
#             <Reaction UDPACGALtex at 0x7f45169e6a90>,
#             <Reaction UDPGALtex at 0x7f45169a1fd0>,
#             <Reaction UDPGLCURtex at 0x7f45169b2ee0>,
#             <Reaction UDPGtex at 0x7f45169b2970>,
#             <Reaction UMPtex at 0x7f451690aac0>,
#             <Reaction URAtex at 0x7f451691f070>,
#             <Reaction UREAtex at 0x7f451690a9a0>,
#             <Reaction VALtex at 0x7f4516933b80>,
#             <Reaction XANtex at 0x7f4516933a60>,
#             <Reaction XMPtex at 0x7f4516949e20>,
#             <Reaction XTSNtex at 0x7f45168df9d0>,
#             <Reaction XYLUtex at 0x7f45168dfb20>,
#             <Reaction XYLtex at 0x7f4516906af0>,
#             <Reaction Zn2tex at 0x7f45169065b0>}),
#  'OmpN': frozenset({<Reaction 12PPDRtex at 0x7f4531a0f850>,
#             <Reaction 12PPDStex at 0x7f4531a0fd30>,
#             <Reaction 23CAMPtex at 0x7f453199c910>,
#             <Reaction 23CCMPtex at 0x7f453199ceb0>,
#             <Reaction 23CGMPtex at 0x7f453199cca0>,
#             <Reaction 23CUMPtex at 0x7f453199cf10>,
#             <Reaction 23DAPPAtex at 0x7f453199c790>,
#             <Reaction 26DAHtex at 0x7f45319b5e50>,
#             <Reaction 34dhpactex at 0x7f453191eac0>,
#             <Reaction 3AMPtex at 0x7f453191ecd0>,
#             <Reaction 3CMPtex at 0x7f4531993430>,
#             <Reaction 3GMPtex at 0x7f4531927f10>,
#             <Reaction 3HPPtex at 0x7f45319558e0>,
#             <Reaction 3PEPTtex at 0x7f45318c7eb0>,
#             <Reaction 3UMPtex at 0x7f45318daf40>,
#             <Reaction 3hoxpactex at 0x7f45168c8c10>,
#             <Reaction 4HOXPACDtex at 0x7f45318daeb0>,
#             <Reaction 4PEPTtex at 0x7f453186ebe0>,
#             <Reaction 4hoxpactex at 0x7f45168c8670>,
#             <Reaction 5DGLCNtex at 0x7f45318da610>,
#             <Reaction 5MTRtex at 0x7f4531884e50>,
#             <Reaction 6APAt1 at 0x7f451685cb80>,
#             <Reaction ABUTtex at 0x7f45318ea2b0>,
#             <Reaction ACACtex at 0x7f4531915ee0>,
#             <Reaction ACALDtex at 0x7f45318a1190>,
#             <Reaction ACGAL1Ptex at 0x7f45318c7df0>,
#             <Reaction ACGALtex at 0x7f45318c7bb0>,
#             <Reaction ACGAM1Ptex at 0x7f45318b6d60>,
#             <Reaction ACGAtex at 0x7f45318c7e50>,
#             <Reaction ACMANAtex at 0x7f453186efd0>,
#             <Reaction ACMUMtex at 0x7f4531884ca0>,
#             <Reaction ACSERtex at 0x7f4531855f70>,
#             <Reaction ACtex at 0x7f45317ef730>,
#             <Reaction ADEtex at 0x7f4531817c70>,
#             <Reaction AGMtex at 0x7f4531795c40>,
#             <Reaction AKGtex at 0x7f4531855ee0>,
#             <Reaction ALAALAtex at 0x7f453183f7c0>,
#             <Reaction ALAtex at 0x7f4531817dc0>,
#             <Reaction ALLTNtex at 0x7f45317d6880>,
#             <Reaction ALLtex at 0x7f45317c2cd0>,
#             <Reaction AMPtex at 0x7f453172ee20>,
#             <Reaction ANHGMtex at 0x7f453172eb80>,
#             <Reaction ARBTtex at 0x7f45315c12e0>,
#             <Reaction ARBtex at 0x7f45314fcd90>,
#             <Reaction ARGtex at 0x7f453144dd30>,
#             <Reaction ASCBtex at 0x7f453140aa60>,
#             <Reaction ASNtex at 0x7f4531358ac0>,
#             <Reaction ASO3tex at 0x7f4531300dc0>,
#             <Reaction ASPtex at 0x7f453172ee80>,
#             <Reaction BALAtex at 0x7f45316eff40>,
#             <Reaction BTNtex at 0x7f4531703d60>,
#             <Reaction BUTSO3tex at 0x7f4531717100>,
#             <Reaction BUTtex at 0x7f45316c3af0>,
#             <Reaction CA2tex at 0x7f45316d7d60>,
#             <Reaction CD2tex at 0x7f4531697e80>,
#             <Reaction CGLYtex at 0x7f4531759af0>,
#             <Reaction CHLtex at 0x7f4531717c40>,
#             <Reaction CHTBStex at 0x7f4531717640>,
#             <Reaction CITtex at 0x7f45316c3250>,
#             <Reaction CLBtex at 0x7f45168c8a90>,
#             <Reaction CLtex at 0x7f4531682940>,
#             <Reaction CMPtex at 0x7f4531682c70>,
#             <Reaction CMtex at 0x7f4531697f70>,
#             <Reaction CO2tex at 0x7f453162deb0>,
#             <Reaction COBALT2tex at 0x7f45316979d0>,
#             <Reaction CRNDtex at 0x7f45315ece80>,
#             <Reaction CRNtex at 0x7f4531603940>,
#             <Reaction CSNtex at 0x7f4531619f40>,
#             <Reaction CU2tex at 0x7f45315c1df0>,
#             <Reaction CUtex at 0x7f45315d7f10>,
#             <Reaction CYANtex at 0x7f45315d7be0>,
#             <Reaction CYNTtex at 0x7f453156ce20>,
#             <Reaction CYSDtex at 0x7f453156c040>,
#             <Reaction CYStex at 0x7f4531596bb0>,
#             <Reaction CYTDtex at 0x7f4531542f70>,
#             <Reaction DALAtex at 0x7f4531619130>,
#             <Reaction DAMPtex at 0x7f4531619bb0>,
#             <Reaction DAPtex at 0x7f45315af9a0>,
#             <Reaction DARBtex at 0x7f4516793cd0>,
#             <Reaction DCAtex at 0x7f453156cbb0>,
#             <Reaction DCMPtex at 0x7f45315d7df0>,
#             <Reaction DDGLCNtex at 0x7f4531580e50>,
#             <Reaction DGMPtex at 0x7f4531596eb0>,
#             <Reaction DGSNtex at 0x7f4531596fd0>,
#             <Reaction DHAtex at 0x7f4531542cd0>,
#             <Reaction DIMPtex at 0x7f45314e88e0>,
#             <Reaction DINStex at 0x7f45314e8e20>,
#             <Reaction DMSOtex at 0x7f4531511f40>,
#             <Reaction DMStex at 0x7f45314a67c0>,
#             <Reaction DOPAtex at 0x7f45314a6d60>,
#             <Reaction DOXRBCNtex at 0x7f45314a6df0>,
#             <Reaction DSERtex at 0x7f45314cfe50>,
#             <Reaction DTMPtex at 0x7f45314cfc70>,
#             <Reaction DUMPtex at 0x7f4531478eb0>,
#             <Reaction D_LACtex at 0x7f4531556ac0>,
#             <Reaction ETHAtex at 0x7f4531438d90>,
#             <Reaction ETHSO3tex at 0x7f4531423f40>,
#             <Reaction ETOHtex at 0x7f4531438dc0>,
#             <Reaction F6Ptex at 0x7f453144db80>,
#             <Reaction FALDtex at 0x7f45313f3a60>,
#             <Reaction FE2tex at 0x7f45313b1d30>,
#             <Reaction FE3tex at 0x7f453132ffd0>,
#             <Reaction FORtex at 0x7f453132fd30>,
#             <Reaction FRULYStex at 0x7f4531346d30>,
#             <Reaction FRUURtex at 0x7f4531358eb0>,
#             <Reaction FRUtex at 0x7f4531358d90>,
#             <Reaction FUCtex at 0x7f4531358f70>,
#             <Reaction FUMtex at 0x7f45312ec9d0>,
#             <Reaction FUSAtex at 0x7f4531300d30>,
# ...
#  'OmpG': frozenset({<Reaction H2Otex at 0x7f452f1a5430>}),
#  'Pgm': frozenset({<Reaction PGMT at 0x7f452ecc69a0>}),
#  'OmpA': frozenset({<Reaction H2Otex at 0x7f452f1a5430>}),
#  'MaeA': frozenset({<Reaction ME1 at 0x7f452ef19fa0>}),
#  'PgpA': frozenset({<Reaction PGPP120 at 0x7f452ec75d30>,
#             <Reaction PGPP120pp at 0x7f452ec75d60>,
#             <Reaction PGPP140 at 0x7f452ec75f10>,
#             <Reaction PGPP140pp at 0x7f452ec5ee80>,
#             <Reaction PGPP141 at 0x7f452ec5edc0>,
#             <Reaction PGPP141pp at 0x7f452ecc6df0>,
#             <Reaction PGPP160 at 0x7f452ec75f70>,
#             <Reaction PGPP160pp at 0x7f452ec75820>,
#             <Reaction PGPP161 at 0x7f452ec5eeb0>,
#             <Reaction PGPP161pp at 0x7f452ec0dd90>,
#             <Reaction PGPP180 at 0x7f452ec0dee0>,
#             <Reaction PGPP180pp at 0x7f452ec0dfd0>,
#             <Reaction PGPP181 at 0x7f452ec0de20>,
#             <Reaction PGPP181pp at 0x7f452ec0dbe0>}),
#  'MaeB': frozenset({<Reaction ME2 at 0x7f452ef2ee20>}),
#  'PgsA': frozenset({<Reaction PGSA120 at 0x7f452ec0dd00>,
#             <Reaction PGSA140 at 0x7f452ec0dd60>,
#             <Reaction PGSA141 at 0x7f452ec24d90>,
#             <Reaction PGSA160 at 0x7f452ec24eb0>,
#             <Reaction PGSA161 at 0x7f452ec24fa0>,
#             <Reaction PGSA180 at 0x7f452ec24f10>,
#             <Reaction PGSA181 at 0x7f452ec37d90>}),
#  'IspG': frozenset({<Reaction MECDPDH2 at 0x7f4516949dc0>,
#             <Reaction MECDPDH5 at 0x7f452ef24c70>}),
#  'AqpZ': frozenset({<Reaction H2Otpp at 0x7f452f1b8ca0>}),
#  'CcmB': frozenset({<Reaction PHEMEabcpp at 0x7f452ec37d60>}),
#  'UbiA': frozenset({<Reaction HBZOPT at 0x7f452f173cd0>}),
#  'CcmE': frozenset({<Reaction PHEMEabcpp at 0x7f452ec37d60>}),
#  'MhpT': frozenset({<Reaction HCINNMt2rpp at 0x7f452f173fa0>,
#             <Reaction HPPPNt2rpp at 0x7f452f102700>}),
#  'CynT': frozenset({<Reaction HCO3E at 0x7f452f185c70>}),
#  'IspF': frozenset({<Reaction MECDPS at 0x7f452ef2eee0>}),
#  'MelB': frozenset({<Reaction MELIBt2pp at 0x7f452ef248b0>}),
#  'CcmC': frozenset({<Reaction PHEMEabcpp at 0x7f452ec37d60>}),
#  'IspD': frozenset({<Reaction MEPCT at 0x7f452ef42ac0>}),
#  'Can': frozenset({<Reaction HCO3E at 0x7f452f185c70>}),
#  'CcmD': frozenset({<Reaction PHEMEabcpp at 0x7f452ec37d60>}),
#  'CyoE': frozenset({<Reaction HEMEOS at 0x7f452f185f10>}),
#  'MetK': frozenset({<Reaction METAT at 0x7f452ef2ef40>}),
#  'CcmA': frozenset({<Reaction PHEMEabcpp at 0x7f452ec37d60>}),
#  'MetN': frozenset({<Reaction METDabcpp at 0x7f452eeda6a0>,
#             <Reaction METabcpp at 0x7f452eefaaf0>}),
#  'PheS': frozenset({<Reaction PHETRS at 0x7f452ebd0af0>}),
#  'MetI': frozenset({<Reaction METDabcpp at 0x7f452eeda6a0>,
#             <Reaction METabcpp at 0x7f452eefaaf0>}),
#  'RfaP': frozenset({<Reaction HEPK1 at 0x7f452f11abb0>,
#             <Reaction HEPKA1 at 0x7f4516841ee0>,
#             <Reaction HEPKB1 at 0x7f45167e9700>}),
#  'PheT': frozenset({<Reaction PHETRS at 0x7f452ebd0af0>}),
#  'PheP': frozenset({<Reaction PHEt2rpp at 0x7f452ebd0b50>,
#             <Reaction TYRt2rpp at 0x7f452ea3c9d0>}),
#  'RfaY': frozenset({<Reaction HEPK2 at 0x7f452f11ad90>,
#             <Reaction HEPKA2 at 0x7f45167d5ee0>,
#             <Reaction HEPKB2 at 0x7f45167e9c40>}),
#  'RfaC': frozenset({<Reaction HEPT1 at 0x7f452f11adf0>,
#             <Reaction HEPTA1 at 0x7f4516841fd0>,
#             <Reaction HEPTB1 at 0x7f4516841f40>}),
#  'MetQ': frozenset({<Reaction METDabcpp at 0x7f452eeda6a0>,
#             <Reaction METabcpp at 0x7f452eefaaf0>}),
#  'MetE': frozenset({<Reaction METS at 0x7f452eeda400>}),
#  'YddG': frozenset({<Reaction PHEt2rpp at 0x7f452ebd0b50>,
#             <Reaction TRPt2rpp at 0x7f4516960fd0>,
#             <Reaction TYRt2rpp at 0x7f452ea3c9d0>}),
#  'RfaF': frozenset({<Reaction HEPT2 at 0x7f452f11ae20>,
#             <Reaction HEPTA2 at 0x7f4516841910>,
#             <Reaction HEPTB2 at 0x7f45167d5bb0>}),
#  'PitA': frozenset({<Reaction PIt2rpp at 0x7f452ec37cd0>}),
#  'RfaQ': frozenset({<Reaction HEPT3 at 0x7f452f11aeb0>,
#             <Reaction HEPTA3 at 0x7f45167d5d60>,
#             <Reaction HEPTB3 at 0x7f45167e9f10>}),
#  'MetH': frozenset({<Reaction METS at 0x7f452eeda400>}),
#  'PitB': frozenset({<Reaction PIt2rpp at 0x7f452ec37cd0>}),
#  'MsrA': frozenset({<Reaction METSOXR1 at 0x7f452eedabe0>}),
#  'MsrB': frozenset({<Reaction METSOXR2 at 0x7f452eeee400>}),
#  'ThiM': frozenset({<Reaction HETZK at 0x7f452f130fa0>}),
#  'PstA': frozenset({<Reaction PIuabcpp at 0x7f452ebe7be0>}),
#  'MetG': frozenset({<Reaction METTRS at 0x7f452eefacd0>}),
#  'PstB': frozenset({<Reaction PIuabcpp at 0x7f452ebe7be0>}),
#  'MgtA': frozenset({<Reaction MG2uabcpp at 0x7f452ee8ceb0>,
#             <Reaction NI2uabcpp at 0x7f452edd58e0>}),
#  'MgsA': frozenset({<Reaction MGSA at 0x7f452eea1fa0>}),
#  'PstS': frozenset({<Reaction PIuabcpp at 0x7f452ebe7be0>}),
#  'MalZ': frozenset({<Reaction MLTG1 at 0x7f452ef3bd90>,
#             <Reaction MLTG2 at 0x7f452ef2ef10>,
#             <Reaction MLTG3 at 0x7f452ef42cd0>,
#             <Reaction MLTG4 at 0x7f452eecf640>,
#             <Reaction MLTG5 at 0x7f452ef3bb50>}),
#  'PstC': frozenset({<Reaction PIuabcpp at 0x7f452ebe7be0>}),
#  'Glk': frozenset({<Reaction HEX1 at 0x7f452f130e20>}),
#  'PldA': frozenset({<Reaction PLIPA1A120pp at 0x7f452ec37fd0>,
#             <Reaction PLIPA1A140pp at 0x7f452ebd0910>,
#             <Reaction PLIPA1A141pp at 0x7f452ebfaa60>,
#             <Reaction PLIPA1A160pp at 0x7f452ebfa9d0>,
#             <Reaction PLIPA1A161pp at 0x7f452ebfa970>,
#             <Reaction PLIPA1A180pp at 0x7f452ecb1e20>,
#             <Reaction PLIPA1A181pp at 0x7f452ecc6bb0>,
#             <Reaction PLIPA1E120pp at 0x7f452ec75ee0>,
#             <Reaction PLIPA1E140pp at 0x7f452ec0d430>,
#             <Reaction PLIPA1E141pp at 0x7f452ec24d00>,
#             <Reaction PLIPA1E160pp at 0x7f452ec24be0>,
#             <Reaction PLIPA1E161pp at 0x7f452ebe7e20>,
#             <Reaction PLIPA1E180pp at 0x7f452ebe7850>,
#             <Reaction PLIPA1E181pp at 0x7f452ebfaee0>,
#             <Reaction PLIPA1G120pp at 0x7f452eb90370>,
#             <Reaction PLIPA1G140pp at 0x7f452eb90f70>,
#             <Reaction PLIPA1G141pp at 0x7f452eba5dc0>,
#             <Reaction PLIPA1G160pp at 0x7f452ebb9970>,
#             <Reaction PLIPA1G161pp at 0x7f452eb64550>,
#             <Reaction PLIPA1G180pp at 0x7f452eb4efd0>,
#             <Reaction PLIPA1G181pp at 0x7f452eb0b460>,
#             <Reaction PLIPA2A120pp at 0x7f452eb20d60>,
#             <Reaction PLIPA2A140pp at 0x7f452eb46df0>,
#             <Reaction PLIPA2A141pp at 0x7f452eb46ac0>,
#             <Reaction PLIPA2A160pp at 0x7f452eb46c10>,
#             <Reaction PLIPA2A161pp at 0x7f452eb46d60>,
#             <Reaction PLIPA2A180pp at 0x7f452eb04eb0>,
#             <Reaction PLIPA2A181pp at 0x7f452eaadd30>,
#             <Reaction PLIPA2E120pp at 0x7f452ea56f70>,
#             <Reaction PLIPA2E140pp at 0x7f452ea56790>,
#             <Reaction PLIPA2E141pp at 0x7f452ea56880>,
#             <Reaction PLIPA2E160pp at 0x7f452ea14d90>,
#             <Reaction PLIPA2E161pp at 0x7f452ea14e20>,
#             <Reaction PLIPA2E180pp at 0x7f452ea3cb80>,
#             <Reaction PLIPA2E181pp at 0x7f45169cff70>,
#             <Reaction PLIPA2G120pp at 0x7f45169e6a60>,
#             <Reaction PLIPA2G140pp at 0x7f45169a18e0>,
#             <Reaction PLIPA2G141pp at 0x7f45169b2c70>,
#             <Reaction PLIPA2G160pp at 0x7f45169b2f10>,
#             <Reaction PLIPA2G161pp at 0x7f4516960d30>,
#             <Reaction PLIPA2G180pp at 0x7f4516976c40>,
#             <Reaction PLIPA2G181pp at 0x7f451690abe0>}),
#  'MltC': frozenset({<Reaction MLTGY1pp at 0x7f452eecf8e0>,
#             <Reaction MLTGY2pp at 0x7f452ef42b50>,
#             <Reaction MLTGY3pp at 0x7f452eee4ee0>,
#             <Reaction MLTGY4pp at 0x7f452eee4ac0>}),
#  'CpsG': frozenset({<Reaction PMANM at 0x7f4516976e20>}),
#  'EmtA': frozenset({<Reaction MLTGY1pp at 0x7f452eecf8e0>,
#             <Reaction MLTGY2pp at 0x7f452ef42b50>,
#             <Reaction MLTGY3pp at 0x7f452eee4ee0>,
#             <Reaction MLTGY4pp at 0x7f452eee4ac0>}),
#  'Mak': frozenset({<Reaction HEX7 at 0x7f452f1308b0>}),
#  'BioH': frozenset({<Reaction PMEACPE at 0x7f45168dff40>}),
#  'HisD': frozenset({<Reaction HISTD at 0x7f452f146910>}),
#  'MltB': frozenset({<Reaction MLTGY1pp at 0x7f452eecf8e0>,
#             <Reaction MLTGY2pp at 0x7f452ef42b50>,
#             <Reaction MLTGY3pp at 0x7f452eee4ee0>,
#             <Reaction MLTGY4pp at 0x7f452eee4ac0>}),
#  'CoaA': frozenset({<Reaction PNTK at 0x7f45168dfcd0>}),
#  'Slt': frozenset({<Reaction MLTGY1pp at 0x7f452eecf8e0>,
#             <Reaction MLTGY2pp at 0x7f452ef42b50>,
#             <Reaction MLTGY3pp at 0x7f452eee4ee0>,
#             <Reaction MLTGY4pp at 0x7f452eee4ac0>}),
#  'MltA': frozenset({<Reaction MLTGY1pp at 0x7f452eecf8e0>,
#             <Reaction MLTGY2pp at 0x7f452ef42b50>,
#             <Reaction MLTGY3pp at 0x7f452eee4ee0>,
#             <Reaction MLTGY4pp at 0x7f452eee4ac0>}),
#  'PanF': frozenset({<Reaction PNTOt4pp at 0x7f45168f1a90>}),
#  'ScpB': frozenset({<Reaction MMCD at 0x7f452eecfcd0>}),
#  'HisB': frozenset({<Reaction HISTP at 0x7f452f146af0>,
#             <Reaction IGPDH at 0x7f452f130f70>}),
#  'RutC': frozenset({<Reaction POAACR at 0x7f451689c9a0>}),
#  'HisS': frozenset({<Reaction HISTRS at 0x7f452f146f40>}),
#  'ScpA': frozenset({<Reaction MMM2 at 0x7f45168f1f40>,
#             <Reaction MMM at 0x7f452eefaa60>}),
#  'MtlA': frozenset({<Reaction MNLptspp at 0x7f452ee8c9d0>}),
#  'YdbK': frozenset({<Reaction POR5 at 0x7f451689c280>}),
#  'UxuA': frozenset({<Reaction MNNH at 0x7f452eefadc0>}),
#  'PoxB': frozenset({<Reaction POX at 0x7f45168b4e50>}),
#  'HisJ': frozenset({<Reaction HISabcpp at 0x7f452f146ca0>}),
#  'Ppx': frozenset({<Reaction PPA2 at 0x7f45168b4eb0>,
#             <Reaction PPA at 0x7f45168b4a00>}),
#  'AroP': frozenset({<Reaction HISt2rpp at 0x7f452f146f10>,
#             <Reaction PHEt2rpp at 0x7f452ebd0b50>,
#             <Reaction TRPt2rpp at 0x7f4516960fd0>,
#             <Reaction TYRt2rpp at 0x7f452ea3c9d0>}),
#  'MoaD': frozenset({<Reaction MOADSUx at 0x7f452ee8cb80>,
#             <Reaction MPTS at 0x7f452eeb7e50>}),
#  'Ppa': frozenset({<Reaction PPA at 0x7f45168b4a00>}),
#  'WaaA': frozenset({<Reaction MOAT2 at 0x7f452ee8cc10>,
#             <Reaction MOAT at 0x7f452eefadf0>}),
#  'MhpC': frozenset({<Reaction HKNDDH at 0x7f452f0efee0>,
#             <Reaction HKNTDH at 0x7f452f0efeb0>}),
#  'HemC': frozenset({<Reaction HMBS at 0x7f452f0dbfd0>}),
#  'ThiD': frozenset({<Reaction HMPK1 at 0x7f452f0efa90>,
#             <Reaction PMPK at 0x7f4516933cd0>}),
#  'PutP': frozenset({<Reaction PPAt4pp at 0x7f45168c8be0>,
#             <Reaction PROt4pp at 0x7f452ec37ca0>}),
#  'PdxK': frozenset({<Reaction HMPK1 at 0x7f452f0efa90>,
#             <Reaction PYDAMK at 0x7f452eb75970>,
#             <Reaction PYDXK at 0x7f452eb75df0>,
#             <Reaction PYDXNK at 0x7f452eb0bcd0>}),
#  'RhtA': frozenset({<Reaction HOMt2pp at 0x7f452f102d60>,
#             <Reaction THRt2pp at 0x7f452ea3ce50>}),
#  'YbhA': frozenset({<Reaction MOBDabcpp at 0x7f452ee8cbb0>,
#             <Reaction PDXPP at 0x7f452ec5ed00>,
#             <Reaction PYDXPP at 0x7f452eb20eb0>,
#             <Reaction SULabcpp at 0x7f452eaadeb0>,
#             <Reaction TUNGSabcpp at 0x7f4516976af0>}),
#  'CysU': frozenset({<Reaction MOBDabcpp at 0x7f452ee8cbb0>,
#             <Reaction SELtpp at 0x7f452ea99eb0>,
#             <Reaction SLNTtpp at 0x7f452ea6bdc0>,
#             <Reaction SULabcpp at 0x7f452eaadeb0>,
#             <Reaction TSULabcpp at 0x7f4516960df0>}),
#  'CysA': frozenset({<Reaction MOBDabcpp at 0x7f452ee8cbb0>,
#             <Reaction SELtpp at 0x7f452ea99eb0>,
#             <Reaction SLNTtpp at 0x7f452ea6bdc0>,
#             <Reaction SULabcpp at 0x7f452eaadeb0>,
#             <Reaction TSULabcpp at 0x7f4516960df0>}),
#  'HemB': frozenset({<Reaction PPBNGS at 0x7f45168c8f40>}),
#  'CysP': frozenset({<Reaction MOBDabcpp at 0x7f452ee8cbb0>,
#             <Reaction SELtpp at 0x7f452ea99eb0>,
#             <Reaction SLNTtpp at 0x7f452ea6bdc0>,
#             <Reaction SULabcpp at 0x7f452eaadeb0>,
#             <Reaction TSULabcpp at 0x7f4516960df0>}),
#  'RhtB': frozenset({<Reaction HOMt2pp at 0x7f452f102d60>}),
#  'Ppc': frozenset({<Reaction PPC at 0x7f45168c8820>}),
#  'MhpE': frozenset({<Reaction HOPNTAL at 0x7f452f102f70>}),
#  'Dfp': frozenset({<Reaction PPCDC at 0x7f451685c550>,
#             <Reaction PPNCL2 at 0x7f45168718e0>}),
#  'Pck': frozenset({<Reaction PPCK at 0x7f451685c3d0>}),
#  'FolK': frozenset({<Reaction HPPK2 at 0x7f452f102f10>}),
#  'Sbp': frozenset({<Reaction MOBDabcpp at 0x7f452ee8cbb0>,
#             <Reaction SULabcpp at 0x7f452eaadeb0>,
#             <Reaction TSULabcpp at 0x7f4516960df0>}),
#  'ScpC': frozenset({<Reaction PPCSCT at 0x7f451685cf40>}),
#  'CysW': frozenset({<Reaction MOBDabcpp at 0x7f452ee8cbb0>,
#             <Reaction SELtpp at 0x7f452ea99eb0>,
#             <Reaction SLNTtpp at 0x7f452ea6bdc0>,
#             <Reaction SULabcpp at 0x7f452eaadeb0>,
#             <Reaction TSULabcpp at 0x7f4516960df0>}),
#  'ModC': frozenset({<Reaction MOBDabcpp at 0x7f452ee8cbb0>,
#             <Reaction SULabcpp at 0x7f452eaadeb0>,
#             <Reaction TUNGSabcpp at 0x7f4516976af0>}),
#  'ModA': frozenset({<Reaction MOBDabcpp at 0x7f452ee8cbb0>,
#             <Reaction SULabcpp at 0x7f452eaadeb0>,
#             <Reaction TUNGSabcpp at 0x7f4516976af0>}),
#  'MocA': frozenset({<Reaction MOCDS at 0x7f452eea1f40>}),
#  'Hyi': frozenset({<Reaction HPYRI at 0x7f452f09bfd0>}),
#  'ThrB': frozenset({<Reaction HSK at 0x7f452f0effa0>}),
#  'MetA': frozenset({<Reaction HSST at 0x7f4531aaccd0>}),
#  'HisC': frozenset({<Reaction HSTPT at 0x7f4531aacc10>}),
#  'Ppk': frozenset({<Reaction PPK2 at 0x7f451685c5b0>,
#             <Reaction PPK at 0x7f451685c7c0>}),
#  'XdhA': frozenset({<Reaction HXAND at 0x7f453ad074c0>,
#             <Reaction XAND at 0x7f45169b2430>}),
#  'DeoB': frozenset({<Reaction PPM2 at 0x7f4516871910>,
#             <Reaction PPM at 0x7f4516871eb0>}),
#  'XdhB': frozenset({<Reaction HXAND at 0x7f453ad074c0>,
#             <Reaction XAND at 0x7f45169b2430>}),
#  'PanB': frozenset({<Reaction MOHMT at 0x7f452eeb7df0>}),
#  'Mog': frozenset({<Reaction MPTAT at 0x7f452eea1c40>}),
#  'PbpC': frozenset({<Reaction MPTG2 at 0x7f452eeb7fd0>,
#             <Reaction MPTG at 0x7f452eefaf10>}),
#  'YhfW': frozenset({<Reaction PPM at 0x7f4516871eb0>}),
#  'MurJ': frozenset({<Reaction LIPIDIIFLIP at 0x7f45167badc0>,
#             <Reaction MPTG2 at 0x7f452eeb7fd0>,
#             <Reaction MPTG at 0x7f452eefaf10>}),
#  'HemG': frozenset({<Reaction PPPGO3 at 0x7f4516887640>,
#             <Reaction PPPGO at 0x7f4516887cd0>}),
#  'MoaE': frozenset({<Reaction MPTS at 0x7f452eeb7e50>}),
#  'XdhC': frozenset({<Reaction HXAND at 0x7f453ad074c0>,
#             <Reaction XAND at 0x7f45169b2430>}),
#  'HcaT': frozenset({<Reaction PPPNt2rpp at 0x7f4516887df0>}),
#  'HyaC': frozenset({<Reaction HYD1pp at 0x7f452f14bd90>,
#             <Reaction HYD2pp at 0x7f452f14be80>,
#             <Reaction HYD3pp at 0x7f452f14bc10>}),
#  'PpsA': frozenset({<Reaction PPS at 0x7f451682fd00>}),
#  'HybO': frozenset({<Reaction HYD1pp at 0x7f452f14bd90>,
#             <Reaction HYD2pp at 0x7f452f14be80>,
#             <Reaction HYD3pp at 0x7f452f14bc10>}),
#  'HyaB': frozenset({<Reaction HYD1pp at 0x7f452f14bd90>,
#             <Reaction HYD2pp at 0x7f452f14be80>,
#             <Reaction HYD3pp at 0x7f452f14bc10>}),
#  'MoeB': frozenset({<Reaction MPTSS at 0x7f452eeb7cd0>}),
#  'PhoA': frozenset({<Reaction PPTHpp at 0x7f451682f160>}),
#  'HyaA': frozenset({<Reaction HYD1pp at 0x7f452f14bd90>,
#             <Reaction HYD2pp at 0x7f452f14be80>,
#             <Reaction HYD3pp at 0x7f452f14bc10>}),
#  'PurD': frozenset({<Reaction PRAGSr at 0x7f452ec0dc40>}),
#  'RutE': frozenset({<Reaction MSAR at 0x7f452ee4be80>}),
#  'PurM': frozenset({<Reaction PRAIS at 0x7f452ed03970>}),
#  'FolD': frozenset({<Reaction MTHFC at 0x7f452ee618e0>,
#             <Reaction MTHFD at 0x7f452ee61cd0>}),
#  'HybA': frozenset({<Reaction HYD1pp at 0x7f452f14bd90>,
#             <Reaction HYD2pp at 0x7f452f14be80>,
#             <Reaction HYD3pp at 0x7f452f14bc10>}),
#  'HisI': frozenset({<Reaction PRAMPC at 0x7f452ec0de80>,
#             <Reaction PRATPP at 0x7f452ec24df0>}),
#  ...}

# %%
one= pd.read_csv("one feasible value reactions lactose.csv")
flat= pd.read_csv("flat lactose.csv")
diff_saturated= pd.read_csv("diff_saturated lactose.csv")
Ushaped= pd.read_csv("Ushaped_reactions lactose.csv")
monotonically_increasingANDstable_reactions= pd.read_csv("monotonically increasing and stable reactions lactose.csv")
monotonically_increasing_only_reactions= pd.read_csv("monotonically increasing only reactions lactose.csv")
monotonically_decreasingANDstable_reactions= pd.read_csv("monotonically decreasing and stable reactions lactose.csv")
monotonically_decreasing_only_reactions= pd.read_csv("monotonically decreasing only reactions lactose.csv")
increasingANDdecreasingANDstable_reactions= pd.read_csv("increasing and decreasing and stable reactions lactose.csv")
increasingANDdecreasing_only_reactions= pd.read_csv("increasing and decreasing only reactions lactose.csv")

# %%
import csv

with open('dictionary.csv', 'w') as f:  
    writer = csv.writer(f)
    for k, v in dictionary.items():
       writer.writerow([k, v])

# %%
import pandas as pd
p= pd.read_csv('dictionary.csv', header= None)
p

headerList= ["Gene name", "Reaction"]
p.to_csv("dictionary_NEW.csv", header=headerList, index=False)
p2 = pd.read_csv("dictionary_NEW.csv")
print('\nModified file:')
print(p2)
# Out:
# Modified file:
#        Gene name                                           Reaction
# 0           PhoE  frozenset({<Reaction CYSDtex at 0x7f453156c040...
# 1           YlbA  frozenset({<Reaction UGCIAMH at 0x7f451670eca0>})
# 2           OmpC  frozenset({<Reaction CYSDtex at 0x7f453156c040...
# 3           OmpF  frozenset({<Reaction CYSDtex at 0x7f453156c040...
# 4           OmpN  frozenset({<Reaction CYSDtex at 0x7f453156c040...
# ...          ...                                                ...
# 1339        YcjT      frozenset({<Reaction MPL at 0x7f4516760e80>})
# 1340        YafJ     frozenset({<Reaction ASNO at 0x7f4516760fd0>})
# 1341        YgdH    frozenset({<Reaction PYRDC at 0x7f4516776d90>})
# 1342  Locus 3025  frozenset({<Reaction HPA3MOFAD at 0x7f4516776b...
# 1343        YcjM     frozenset({<Reaction SUCP at 0x7f4516776c70>})
#
# [1344 rows x 2 columns]

# %%
boolean_findings = p2['Reaction'].str.contains('UGCIAMH')

boolean_findings

i=0
gene_names= list()
while i <1343:
    if boolean_findings[i] ==True:
        
        l= p2.iloc[i, 0]
        gene_names.append(l)
    i=i+1
gene_names
# Out:
# ['YlbA']

# %%
diff_saturated["Reaction names"]
# Out:
# 0          EX_ppt_e
# 1          EX_fe2_e
# 2     ACOLIPAabctex
# 3               ADA
# 4               ADD
#           ...
# 87              POX
# 88              PPK
# 89              PPM
# 90    L_LACD2_copy2
# 91      XTSNH_copy2
# Name: Reaction names, Length: 92, dtype: object

# %%
z=0
saturated_gene_names= list()
l= str()

while z< len(diff_saturated):

    boolean_findings = p2['Reaction'].str.contains(diff_saturated["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            saturated_gene_names.append(l)
        i=i+1
    
    z=z+1

saturated_gene_names
# Out:
# ['FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'Add',
#  'LpxC',
#  'RffT',
#  'Ade',
#  'LigA',
#  'NudC',
#  'Add',
#  'FadB',
#  'FadB',
#  'DadA',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'CysI',
#  'CysJ',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GltP',
#  'GlxK',
#  'GarK',
#  'GhrB',
#  'GhrA',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'LldD',
#  'YkgF',
#  'YkgE',
#  'YkgG',
#  'LldD',
#  'YkgF',
#  'YkgE',
#  'YkgG',
#  'ScpA',
#  'AcnB',
#  'Dgt',
#  'Sad',
#  'SucD',
#  'SucC',
#  'DsdA',
#  'TnaA',
#  'SdaA',
#  'TdcG',
#  'SdaB',
#  'GlyA',
#  'LtaE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Deleted',
#  'YdfG',
#  'CydD',
#  'CydC',
#  'Ggt',
#  'GsiA',
#  'GsiB',
#  'GsiC',
#  'GsiD',
#  'Tdh',
#  'IlvA',
#  'TrpA',
#  'TrpB',
#  'GlxR',
#  'GarR',
#  'RihC',
#  'LldD',
#  'ScpA',
#  'LldD',
#  'RihC',
#  'RihA',
#  'RihB']

# %%
z=0
one_gene_names= list()
l= str()

while z< len(one):

    boolean_findings = p2['Reaction'].str.contains(one['1 feasible value'][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            one_gene_names.append(l)
        i=i+1
    
    z=z+1

one_gene_names
# Out:
# ['LamB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MhpA',
#  'RffT',
#  'MalS',
#  'MhpA',
#  'LyxK',
#  'BglA',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'AtoE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NhoA',
#  'CobU',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Rfe',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TynA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ThrC',
#  'RffM',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'MurP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NanT',
#  'Mtn',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GutQ',
#  'KdsD',
#  'OmpC',
#  'OmpF',
#  'Deleted',
#  'NanA',
#  'S0001',
#  'Tam',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'Mtn',
#  'Aas',
#  'AcpP',
#  'AcpT',
#  'AcpS',
#  'PabC',
#  'PabA',
#  'PabB',
#  'AlaS',
#  'Tsx',
#  'CobU',
#  'CobS',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'AlsK',
#  'RpiB',
#  'AlsE',
#  'AlsC',
#  'AlsB',
#  'AlsA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UxaA',
#  'MalQ',
#  'NanE',
#  'NanK',
#  'RfaD',
#  'BioA',
#  'UbiE',
#  'ThiC',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'BioF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ApaH',
#  'AspS',
#  'SpeE',
#  'ArsC',
#  'GrxB',
#  'QueF',
#  'IspE',
#  'Cfa',
#  'Cfa',
#  'Cfa',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Cfa',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MoeA',
#  'MobB',
#  'MobA',
#  'MobB',
#  'MobA',
#  'BetA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BioB',
#  'UbiC',
#  'PtsI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TauB',
#  'TauC',
#  'TauA',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'HcaF',
#  'HcaD',
#  'HcaE',
#  'HcaC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MobB',
#  'MobA',
#  'MobB',
#  'MobA',
#  'MoeA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BtuR',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'BtuR',
#  'ClcB',
#  'ClcA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'QueC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GldA',
#  'LpxT',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'MsbA',
#  'RibD',
#  'MoaC',
#  'MoaA',
#  'HemN',
#  'CaiB',
#  'CaiD',
#  'CaiB',
#  'AraA',
#  'CaiD',
#  'CaiC',
#  'QueD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CaiT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Tsx',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YgeX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RibB',
#  'BioD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlpE',
#  'PspE',
#  'PspE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CynS',
#  'CynX',
#  'ChbF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FadL',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Tsx',
#  'FadL',
#  'DgoK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CsdA',
#  'KdgT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MetC',
#  'MalY',
#  'CysS',
#  'DgoA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'AscF',
#  'BglF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'HcaB',
#  'MhpB',
#  'MhpB',
#  'FolC',
#  'FolM',
#  'MenA',
#  'MenB',
#  'YbgC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DkgB',
#  'DkgA',
#  'FolB',
#  'IspA',
#  'RibD',
#  'HcaB',
#  'UbiG',
#  'RibD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FolP',
#  'S0001',
#  'NfsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NudB',
#  'MutT',
#  'NfsB',
#  'FolX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CoaE',
#  'NudF',
#  'NudE',
#  'IlvC',
#  'PanE',
#  'DapB',
#  'NadC',
#  'WzyE',
#  'WzzE',
#  'WzyE',
#  'WzzE',
#  'WzyE',
#  'WzzE',
#  'WzxE',
#  'DsbC',
#  'TrxA',
#  'TrxC',
#  'DsbD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FumB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Tsx',
#  'LpxL',
#  'LpxM',
#  'LpxP',
#  'LpxM',
#  'FabI',
#  'ArgS',
#  'Dxr',
#  'Dxs',
#  'XylB',
#  'Epd',
#  'GapA',
#  'FabI',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UlaG',
#  'PtsH',
#  'PtsI',
#  'UlaC',
#  'UlaB',
#  'UlaA',
#  'FrmA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'FadK',
#  'FadD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'FucI',
#  'FucK',
#  'FucA',
#  'YgbL',
#  'HemH',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'Fmt',
#  'FecB',
#  'FecD',
#  'FecC',
#  'FecE',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FecA',
#  'FepG',
#  'FepC',
#  'FepD',
#  'FepB',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'CirA',
#  'Fiu',
#  'RibF',
#  'AsnS',
#  'Frc',
#  'FruK',
#  'FrlB',
#  'FrlC',
#  'FrlD',
#  'FrlA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GntP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'FruB',
#  'FruA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ArsB',
#  'RffH',
#  'RfbA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SuhB',
#  'AphA',
#  'YihU',
#  'PanD',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Maa',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GarL',
#  'GudX',
#  'GudD',
#  'GudP',
#  'GarP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GarD',
#  'YjjN',
#  'DgoD',
#  'YjjL',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RfaG',
#  'RfaI',
#  'DgoT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GudP',
#  'GarP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ExuT',
#  'KdgT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MelA',
#  'PtsH',
#  'PtsI',
#  'GatC',
#  'GatA',
#  'GatB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ExuT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlnS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GatD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AldA',
#  'Fcl',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UxaC',
#  'UxaC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'IscU',
#  'IscS',
#  'IscU',
#  'IscS',
#  'CyaY',
#  'UbiA',
#  'MhpT',
#  'IscU',
#  'IscS',
#  'CyaY',
#  'IscU',
#  'IscA',
#  'IscU',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IscU',
#  'IscA',
#  'FadL',
#  'FadL',
#  'CyoE',
#  'IscS',
#  'RfaP',
#  'RfaY',
#  'RfaC',
#  'RfaF',
#  'RfaQ',
#  'ThiM',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IleS',
#  'HisS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MhpC',
#  'MhpC',
#  'HemC',
#  'ThiD',
#  'PdxK',
#  'YidK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Tsx',
#  'Idi',
#  'MhpE',
#  'FolK',
#  'MhpB',
#  'MhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TauB',
#  'TauC',
#  'TauA',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'MetA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MsbA',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'KdsB',
#  'GlyQ',
#  'GlyS',
#  'KdsC',
#  'KdsA',
#  'YiaQ',
#  'UlaD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ArnT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Gmd',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LeuS',
#  'RfaE',
#  'MsbA',
#  'PagP',
#  'RfaE',
#  'PagP',
#  'LplA',
#  'LplA',
#  'MsbA',
#  'LipA',
#  'GmhB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LpxB',
#  'LysU',
#  'LysS',
#  'RhaA',
#  'RhaT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MtlD',
#  'BioC',
#  'DmlA',
#  'DctA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UxuB',
#  'PtsH',
#  'PtsI',
#  'MngA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Maa',
#  'LamB',
#  'MngB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LamB',
#  'LamB',
#  'LamB',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'MalX',
#  'LamB',
#  'Fcl',
#  'SseA',
#  'ManA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ApaH',
#  'UgpQ',
#  'GlpQ',
#  'GlpQ',
#  'IspF',
#  'MalZ',
#  'MalZ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'IspD',
#  'MetN',
#  'MetI',
#  'MetQ',
#  'UgpQ',
#  'GlpQ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TrxA',
#  'TrxC',
#  'BisC',
#  'MetE',
#  'MetH',
#  'MsrA',
#  'MsrB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Fmt',
#  'MetG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UxuA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MoaD',
#  'IscS',
#  'WaaA',
#  'SuhB',
#  'WaaA',
#  'YbhA',
#  'CysU',
#  'CysA',
#  'CysP',
#  'Sbp',
#  'CysW',
#  'ModC',
#  'ModA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MocA',
#  'MoeA',
#  'MobB',
#  'MobA',
#  'UgpQ',
#  'GlpQ',
#  'PanB',
#  'Mog',
#  'GlpQ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IspA',
#  'MoaD',
#  'MoaE',
#  'MoeB',
#  'MoeB',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  ...]

# %%
z=0
flat_gene_names= list()
l= str()

while z< len(flat):

    boolean_findings = p2['Reaction'].str.contains(flat["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            flat_gene_names.append(l)
        i=i+1
    
    z=z+1

flat_gene_names
# Out:
# ['GhrB',
#  'GhrB',
#  'GhrB',
#  'GabP',
#  'FadA',
#  'AtoB',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'Acs',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'GlcA',
#  'LldP',
#  'ActP',
#  'GlyA',
#  'LtaE',
#  'AlaA',
#  'AlaC',
#  'CycA',
#  'YaaJ',
#  'Adk',
#  'Adk',
#  'FeaB',
#  'MalQ',
#  'MalQ',
#  'MalQ',
#  'GltP',
#  'BetB',
#  'BisC',
#  'ChaA',
#  'YrbG',
#  'CaiC',
#  'ProP',
#  'CaiT',
#  'CaiC',
#  'FadB',
#  'CueO',
#  'FolB',
#  'PyrD',
#  'GhrB',
#  'GhrB',
#  'IspH',
#  'FabI',
#  'FabI',
#  'FabI',
#  'DsbB',
#  'DsbA',
#  'FabI',
#  'FabI',
#  'FabI',
#  'Fau',
#  'GlgB',
#  'GlgP',
#  'MalP',
#  'GlgP',
#  'MalP',
#  'GlgA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LamB',
#  'GlgX',
#  'GlgC',
#  'GadC',
#  'GltS',
#  'GlcA',
#  'LldP',
#  'ActP',
#  'FadJ',
#  'FadB',
#  'HycC',
#  'HycG',
#  'HycE',
#  'HycD',
#  'HycF',
#  'HycB',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'MenF',
#  'EntC',
#  'TolC',
#  'AcrF',
#  'AcrE',
#  'Mtr',
#  'IspH',
#  'Hyi',
#  'GhrB',
#  'GhrA',
#  'FabB',
#  'FabF',
#  'FabH',
#  'CycA',
#  'YeaV',
#  'YaaJ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BglX',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'FldB',
#  'FldA',
#  'IspG',
#  'NarH',
#  'NarG',
#  'NarY',
#  'NarW',
#  'NarZ',
#  'NarV',
#  'NarI',
#  'NarJ',
#  'ChaA',
#  'MdfA',
#  'Adk',
#  'Ndk',
#  'Hmp',
#  'NorV',
#  'NorW',
#  'LplA',
#  'PdxH',
#  'ProP',
#  'PutP',
#  'YgiN',
#  'PhnN',
#  'Deleted',
#  'SdaC',
#  'SstT',
#  'GlyA',
#  'TrpA',
#  'TrpB',
#  'UraA',
#  'RutG',
#  'AvtA',
#  'IlvE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcnB',
#  'MenB',
#  'FadB',
#  'FadB',
#  'AvtA',
#  'ScpC',
#  'GhrB',
#  'FeaB',
#  'FolB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'AraE',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'YdeA',
#  'FadJ',
#  'FadB',
#  'FadB',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'YiaK']

# %%
z=0
Ushaped_gene_names= list()
l= str()

while z< len(Ushaped):

    boolean_findings = p2['Reaction'].str.contains(Ushaped["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            Ushaped_gene_names.append(l)
        i=i+1
    
    z=z+1

Ushaped_gene_names
# Out:
# ['PtsH',
#  'PtsI',
#  'DhaK',
#  'DhaL',
#  'DhaM',
#  'AsnB',
#  'CueO',
#  'GarK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'Gpp',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB']

# %%
z=0
monotonically_increasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasingANDstable_reactions_gene_names
# Out:
# ['ProP',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DsbB',
#  'DsbA',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PtsH',
#  'Crr',
#  'PtsG',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'MalX',
#  'GalP',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'LacZ',
#  'BglX',
#  'NarH',
#  'NarG',
#  'NarY',
#  'NarW',
#  'NarZ',
#  'NarV',
#  'NarI',
#  'NarJ',
#  'YgiN',
#  'SodA',
#  'SodB',
#  'SodC',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'IspG',
#  'PreB',
#  'PreA']

# %%
z=0
monotonically_increasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasing_only_reactions_gene_names
# Out:
# ['PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GhrB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoA',
#  'AtoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'PtsH',
#  'NagE',
#  'Crr',
#  'PtsG',
#  'PtsI',
#  'IlvN',
#  'IlvI',
#  'IlvH',
#  'IlvB',
#  'IdnO',
#  'IdnT',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'KgtP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'XanP',
#  'PurP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Adk',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FrmA',
#  'AdhE',
#  'FrmA',
#  'AdhP',
#  'AldB',
#  'NupC',
#  'NupG',
#  'YbbW',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Lpp',
#  'Lnt',
#  'Lpp',
#  'Lnt',
#  'TrpD',
#  'TrpE',
#  'GlpE',
#  'PspE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TrpD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YdfG',
#  'HisG',
#  'CycA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BetT',
#  'YeaV',
#  'BetB',
#  'BisC',
#  'PheA',
#  'TyrA',
#  'AroC',
#  'MenF',
#  'EntC',
#  'AtoA',
#  'AtoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'HemF',
#  'HemN',
#  'NupC',
#  'NupG',
#  'CodB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LysA',
#  'DapF',
#  'ProP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'NupC',
#  'NupG',
#  'KdgK',
#  'AroG',
#  'AroF',
#  'AroH',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'IlvD',
#  'NupC',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlcA',
#  'LldP',
#  'DapB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AroD',
#  'DapA',
#  'NupG',
#  'YiaK',
#  'AroB',
#  'YdfG',
#  'CycA',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'NupC',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UhpT',
#  'FadK',
#  'FadD',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AnsP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'Agp',
#  'AphA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Agp',
#  'NadB',
#  'GalK',
#  'WcaK',
#  'GalM',
#  'GlnQ',
#  'GlnP',
#  'GlnH',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'AnsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlpF',
#  'YeaV',
#  'ProP',
#  'Tsx',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GudP',
#  'GarP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IdnT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'HisF',
#  'HisH',
#  'HisB',
#  'TrpC',
#  'AtoE',
#  'FieF',
#  'BrnQ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'HisD',
#  'HisB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AroP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LeuB',
#  'LeuA',
#  'HisC',
#  'IlvC',
#  'GlcA',
#  'LldP',
#  'PldB',
#  'YjdL',
#  'DtpA',
#  'DtpB',
#  'DtpD',
#  'PldB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PldB',
#  'PldB',
#  'PldB',
#  'YjdL',
#  'DtpA',
#  'DtpB',
#  'DtpD',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'TyrB',
#  'IlvE',
#  'BrnQ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LipB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UhpT',
#  'MetK',
#  'GlpQ',
#  'MalP',
#  'MalP',
#  'MalP',
#  'MetN',
#  'MetI',
#  'MetQ',
#  'PtsH',
#  'PtsI',
#  'MtlA',
#  'NupG',
#  'Hmp',
#  'PnuC',
#  'S0001',
#  'UbiF',
#  'UbiH',
#  'UbiB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'YqaB',
#  'Pgm',
#  'TrpC',
#  'HisI',
#  'HisI',
#  'HisA',
#  'PheP',
#  'YddG',
#  'AroP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AroA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AphA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YdiB',
#  'AraB',
#  'AphA',
#  'PotE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AlsC',
#  'AlsB',
#  'AlsA',
#  'YtfR',
#  'YtfT',
#  'YjfF',
#  'YtfQ',
#  'RbsC',
#  'RbsA',
#  'RbsD',
#  'RbsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'SrlB',
#  'SrlA',
#  'SrlE',
#  'DapE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'DcuB',
#  'FumB',
#  'DmlA',
#  'TtdA',
#  'TtdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YeiG',
#  'FrmB',
#  'YdiB',
#  'AroE',
#  'AroK',
#  'AroL',
#  'ShiA',
#  'CysU',
#  'CysA',
#  'CysP',
#  'CysW',
#  'DapD',
#  'NupC',
#  'NupG',
#  'PheP',
#  'YddG',
#  'AroP',
#  'TyrP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'TreB',
#  'GalT',
#  'AphA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpsG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlpF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupC',
#  'NupG',
#  'BrnQ',
#  'YgaH',
#  'YgaZ',
#  'PanF',
#  'XylE',
#  'PutP',
#  'HemB',
#  'PheA',
#  'TyrA',
#  'HcaF',
#  'HcaD',
#  'HcaE',
#  'HcaC',
#  'MhpB',
#  'PheA',
#  'HemG',
#  'GhrB',
#  'DmlA']

# %%
z=0
monotonically_decreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasingANDstable_reactions_gene_names
# Out:
# ['LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'DdpX',
#  'GlyA',
#  'LtaE',
#  'DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'PuuC',
#  'RihC',
#  'AldB',
#  'Apt',
#  'Amn',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ZntA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'ZntA',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'CopA',
#  'CydD',
#  'CydC',
#  'AppC',
#  'AppB',
#  'AppC',
#  'AppB',
#  'CydB',
#  'CydA',
#  'AraG',
#  'AraF',
#  'AraH',
#  'YdeA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ArtM',
#  'ArtJ',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'ArtP',
#  'ArtI',
#  'ArtQ',
#  'YbiV',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'FbaA',
#  'FadK',
#  'FadD',
#  'AnsB',
#  'FeoB',
#  'MntH',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'GlpA',
#  'GlpD',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'NadB',
#  'YbiV',
#  'NadB',
#  'NadB',
#  'MglC',
#  'MglA',
#  'MglB',
#  'AspA',
#  'AspC',
#  'AspS',
#  'YtfR',
#  'YtfT',
#  'MglC',
#  'MglA',
#  'YjfF',
#  'YtfQ',
#  'MglB',
#  'PabB',
#  'AnsB',
#  'YbaS',
#  'YneH',
#  'NudK',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'XanP',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'Gpt',
#  'Hpt',
#  'IdnD',
#  'Glk',
#  'ZntA',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'HisJ',
#  'RihC',
#  'GhrB',
#  'GhrA',
#  'YdeA',
#  'SetB',
#  'SetA',
#  'LacY',
#  'Dld',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'LivK',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'DcuA',
#  'DcuB',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'Mqo',
#  'Mqo',
#  'MaeA',
#  'MalZ',
#  'MalZ',
#  'MalZ',
#  'YbiV',
#  'CorA',
#  'MgtA',
#  'Ndh',
#  'Ndh',
#  'Ndh',
#  'MdaB',
#  'MdaB',
#  'MdaB',
#  'PntA',
#  'PntB',
#  'SthA',
#  'NhaB',
#  'NhaA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'ZntA',
#  'BtuE',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'NapA',
#  'NapC',
#  'NapB',
#  'HscC',
#  'RsgA',
#  'YjjX',
#  'RsgA',
#  'YjjX',
#  'RsgA',
#  'AppA',
#  'RsgA',
#  'MutT',
#  'MazG',
#  'RdgB',
#  'MutT',
#  'MazG',
#  'NudI',
#  'MazG',
#  'NudG',
#  'MazG',
#  'NudG',
#  'NudB',
#  'MazG',
#  'MazG',
#  'NudI',
#  'MazG',
#  'MazG',
#  'Dgt',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'Eda',
#  'PfkA',
#  'PfkB',
#  'Gpt',
#  'Hpt',
#  'ProX',
#  'ProV',
#  'ProW',
#  'YbiV',
#  'AphA',
#  'PotD',
#  'PotB',
#  'PotF',
#  'YdcS',
#  'YdcV',
#  'PotA',
#  'PotI',
#  'PotH',
#  'PotG',
#  'PotC',
#  'YdcU',
#  'YdcT',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'DcuA',
#  'DcuB',
#  'TrxA',
#  'TrxC',
#  'BtuE',
#  'Bcp',
#  'GlyA',
#  'LtaE',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'Upp',
#  'RihC',
#  'RihA',
#  'RihB',
#  'XanP',
#  'XanQ',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'XylH',
#  'XylG',
#  'XylF',
#  'ZntA',
#  'PoxB',
#  'SolA',
#  'Ppx',
#  'SurE',
#  'FolK',
#  'Ppk',
#  'DeoB',
#  'YhfW',
#  'LeuC',
#  'LeuD',
#  'AraG',
#  'AraF',
#  'AraH']

# %%
z=0
monotonically_decreasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasing_only_reactions_gene_names
# Out:
# ['LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'NudJ',
#  'Cof',
#  'FabA',
#  'FabZ',
#  'RutD',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'Aas',
#  'AcpP',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'Aas',
#  'AcpP',
#  'GabT',
#  'PuuE',
#  'Prr',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabB',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabB',
#  'FabF',
#  'FabF',
#  'FabB',
#  'FabF',
#  'NagK',
#  'FabB',
#  'FabF',
#  'OppF',
#  'MppA',
#  'OppB',
#  'OppC',
#  'OppD',
#  'MurQ',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'PlsC',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'EamA',
#  'EamB',
#  'YcjG',
#  'SpeD',
#  'CyaA',
#  'NudF',
#  'NudE',
#  'AllC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AllB',
#  'YbbW',
#  'NagA',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'DkgB',
#  'DkgA',
#  'Gpr',
#  'YeaE',
#  'GldA',
#  'AmpD',
#  'NagZ',
#  'AmpG',
#  'NagZ',
#  'RfaD',
#  'SpeB',
#  'AmpG',
#  'PlsC',
#  'PlsC',
#  'S0001',
#  'PlsC',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'AnmK',
#  'PlsC',
#  'ApaH',
#  'LysU',
#  'PlsY',
#  'PlsY',
#  'PlsY',
#  'AstA',
#  'S0001',
#  'PlsY',
#  'DppF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'PlsY',
#  'CadB',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ZupT',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuE',
#  'CodA',
#  'CdsA',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'CdsA',
#  'CdsA',
#  'ZntA',
#  'S0001',
#  'CdsA',
#  'CdsA',
#  'S0001',
#  'Cdd',
#  'EntA',
#  'EntE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DeoC',
#  'YdgI',
#  'Eda',
#  'RhmA',
#  'Edd',
#  'PreB',
#  'PreA',
#  'NudI',
#  'Dut',
#  'EntD',
#  'EutB',
#  'EutC',
#  'ArgO',
#  'TesB',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'S0001',
#  'FieF',
#  'YtfE',
#  'HycC',
#  'HycG',
#  'HycE',
#  'HyfI',
#  'HycD',
#  'HycF',
#  'HyfE',
#  'HycB',
#  'HyfC',
#  'HyfJ',
#  'FdhF',
#  'HyfF',
#  'HyfG',
#  'HyfA',
#  'HyfB',
#  'HyfH',
#  'HyfD',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'FocB',
#  'FocA',
#  'Fre',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'FepG',
#  'FepC',
#  'FepD',
#  'FepB',
#  'S0001',
#  'TolC',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FepA',
#  'EntS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ProA',
#  'Gcd',
#  'YliI',
#  'IdnT',
#  'KdgT',
#  'GntP',
#  'GntT',
#  'GntU',
#  'GalU',
#  'ProB',
#  'GshA',
#  'Gcl',
#  'PuuC',
#  'PuuD',
#  'PuuB',
#  'PuuA',
#  'S0001',
#  'EntB',
#  'IlvE',
#  'RhtA',
#  'RhtB',
#  'GloB',
#  'LeuC',
#  'LeuD',
#  'LeuC',
#  'LeuD',
#  'TesA',
#  'TesA',
#  'ChaA',
#  'KefC',
#  'KefB',
#  'MdfA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'MpaA',
#  'PepD',
#  'AldA',
#  'FucO',
#  'S0001',
#  'GloA',
#  'TesA',
#  'YdfG',
#  'LdcC',
#  'CadA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'ArgO',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'PrpD',
#  'PrpB',
#  'PrpC',
#  'CpsB',
#  'MrcB',
#  'MrcA',
#  'FtsI',
#  'MrcB',
#  'MrcA',
#  'MrdA',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'DacB',
#  'PbpG',
#  'MepA',
#  'DacB',
#  'PbpG',
#  'MepA',
#  'DacB',
#  'PbpG',
#  'MepA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpQ',
#  'GlpQ',
#  'MelB',
#  'YdeA',
#  'GlpQ',
#  'S0001',
#  'Deleted',
#  'MltC',
#  'EmtA',
#  'MltB',
#  'Slt',
#  'MltA',
#  'Deleted',
#  'MltC',
#  'EmtA',
#  'MltB',
#  'Slt',
#  'MltA',
#  'S0001',
#  'ScpB',
#  'TrxA',
#  'TrxC',
#  'BisC',
#  'MsrA',
#  'TrxA',
#  'TrxC',
#  'MsrB',
#  'ZitB',
#  'FieF',
#  'UgpQ',
#  'GlpQ',
#  'MrcB',
#  'MrcA',
#  'PbpC',
#  'MurJ',
#  'LigA',
#  'NudC',
#  'YdfG',
#  'RutE',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'Mtn',
#  'PncB',
#  'Gss',
#  'Gss',
#  'Adk',
#  'Ndk',
#  'S0001',
#  'AphA',
#  'SurE',
#  'UshA',
#  'Gor',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'Ggt',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'PncA',
#  'CydD',
#  'CydC',
#  'RdgB',
#  'RdgB',
#  'GshB',
#  'RdgB',
#  'RelA',
#  'S0001',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'PldA',
#  'DosP',
#  'CpdB',
#  'DosP',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'YbhA',
#  'MsbA',
#  'MsbA',
#  'PldA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'MsbA',
#  'PldA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PldA',
#  'PgsA',
#  'PgsA',
#  'PldA',
#  'PgsA',
#  'PgsA',
#  'PgsA',
#  'PgsA',
#  'PgsA',
#  'AspC',
#  'TyrB',
#  'IlvE',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'Psd',
#  'PldA',
#  'Psd',
#  'Psd',
#  'PldA',
#  'PldA',
#  'PldA',
#  'Psd',
#  'PldA',
#  'Psd',
#  'PldA',
#  'PssA',
#  'PssA',
#  'PssA',
#  'PldA',
#  'PldA',
#  'PssA',
#  'PssA',
#  'RbsK',
#  'AraB',
#  'S0001',
#  'PatA',
#  'PldA',
#  'PldA',
#  'Deleted',
#  'DeoD',
#  'PldA',
#  'Deleted',
#  'DeoD',
#  'PdxH',
#  'PdxK',
#  'PdxK',
#  'PdxY',
#  'PdxK',
#  'PldA',
#  'Cof',
#  'YbhA',
#  'YigL',
#  'RutF',
#  'RutA',
#  'PldA',
#  'MdtJ',
#  'MdtI',
#  'SpeE',
#  'PldA',
#  'PldA',
#  'AstB',
#  'PldA',
#  'PldA',
#  'ArgD',
#  'PldA',
#  'PldA',
#  'EntF',
#  'FabA',
#  'PldA',
#  'AstE',
#  'PldA',
#  'AstD',
#  'PldA',
#  'NudJ',
#  'IspB',
#  'RffC',
#  'RffA',
#  'RfbC',
#  'RfbD',
#  'RfbB',
#  'RffG',
#  'PldA',
#  'AstC',
#  'PldA',
#  'AspC',
#  'TyrB',
#  'PldA',
#  'RhtA',
#  'RhtC',
#  'PldA',
#  'PldA',
#  'DeoA',
#  'PldA',
#  'GalE',
#  'TrxA',
#  'TrxC',
#  'TrxB',
#  'OtsB',
#  'OtsA',
#  'PldA',
#  'TreF',
#  'TreA',
#  'TnaA',
#  'PldA',
#  'PldA',
#  'LdcA',
#  'PldA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Mpl',
#  'RutB',
#  'PldA',
#  'AllD',
#  'XdhA',
#  'XdhB',
#  'XdhC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RutC',
#  'SpoT',
#  'DeoB',
#  'FldB',
#  'FldA',
#  'Fpr']

# %%
z=0
increasingANDdecreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasingANDstable_reactions_gene_names
# Out:
# ['PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'OmpL',
#  'OmpG',
#  'OmpA',
#  'Pta',
#  'EutD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcpP',
#  'PlsX',
#  'NudB',
#  'MutT',
#  'Cdh',
#  'GmhB',
#  'Ppx',
#  'Ppa',
#  'PutP',
#  'SurE',
#  'S0001',
#  'MgtA',
#  'NikC',
#  'NikE',
#  'NikD',
#  'NikB',
#  'NikA',
#  'FsaA',
#  'FsaB',
#  'PyrD',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'Mak',
#  'Deleted',
#  'KdpB',
#  'KdpC',
#  'KdpA',
#  'GlyA',
#  'LtaE',
#  'IaaA',
#  'AnsA',
#  'AnsB',
#  'Lpd',
#  'FldB',
#  'FldA',
#  'Zwf',
#  'AceF',
#  'AceE',
#  'IspG',
#  'HisB',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH',
#  'Adk',
#  'AtoA',
#  'AtoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AdhE',
#  'MhpF',
#  'S0001',
#  'Gsk',
#  'YbhA',
#  'CysU',
#  'CysA',
#  'CysP',
#  'Sbp',
#  'CysW',
#  'ModC',
#  'ModA',
#  'Lpd',
#  'SucB',
#  'SucA',
#  'Udk',
#  'SpeA',
#  'HemF',
#  'HemN',
#  'HemG',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'PykA',
#  'PykF',
#  'ZnuC',
#  'ZnuA',
#  'ZnuB',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'Gsk',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'Prs',
#  'YdjI',
#  'FbaB',
#  'FbaA',
#  'TalB',
#  'TalA',
#  'XylA',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'MntH',
#  'PfkA',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'CarA',
#  'CarB',
#  'YgdH',
#  'Pck',
#  'Deleted',
#  'PurT',
#  'AckA',
#  'SdhD',
#  'SdhA',
#  'SdhB',
#  'SdhC',
#  'PstA',
#  'PstB',
#  'PstS',
#  'PstC',
#  'GltD',
#  'GltB',
#  'NapG',
#  'NapA',
#  'NapC',
#  'NapB',
#  'NapH',
#  'PurT',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'NirB',
#  'NirD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN']

# %%
z=0
increasingANDdecreasing_only_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasing_only_reactions_gene_names
# Out:
# ['GuaD',
#  'FabB',
#  'FabF',
#  'TreC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Pgl',
#  'Gph',
#  'CdsA',
#  'MsbA',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'FabI',
#  'MurB',
#  'CynT',
#  'Can',
#  'Pgk',
#  'Tdk',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'Tdk',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'IdnD',
#  'GlpX',
#  'YggF',
#  'Fbp',
#  'TesB',
#  'Aas',
#  'PotD',
#  'PotB',
#  'YdcS',
#  'YdcV',
#  'PotA',
#  'PotC',
#  'YdcU',
#  'YdcT',
#  'AcpP',
#  'FabH',
#  'S0001',
#  'AqpZ',
#  'CysC',
#  'Aas',
#  'Aas',
#  'AcpP',
#  'Cdh',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PurA',
#  'LpxB',
#  'AccA',
#  'AccC',
#  'AccD',
#  'AccB',
#  'GuaB',
#  'SpoT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RihC',
#  'NupC',
#  'NupG',
#  'Cdd',
#  'RihA',
#  'RihB',
#  'Udk',
#  'SpeC',
#  'SpeF',
#  'GltX',
#  'PurM',
#  'Fre',
#  'TdcE',
#  'PflA',
#  'YfiD',
#  'PflB',
#  'NadD',
#  'DctA',
#  'YbiV',
#  'PgpB',
#  'PgpA',
#  'AcpP',
#  'PlsX',
#  'Gmk',
#  'PurB',
#  'AcpH',
#  'AceA',
#  'PotE',
#  'PuuP',
#  'YccX',
#  'GuaA',
#  'Cmk',
#  'AcpP',
#  'FabD',
#  'Mpl',
#  'TesB',
#  'MurI',
#  'MraY',
#  'Adk',
#  'Ndk',
#  'ThrA',
#  'LysC',
#  'MetL',
#  'GlyA',
#  'PlsY',
#  'FadE',
#  'AllA',
#  'FolD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'GlpF',
#  'DacB',
#  'PbpG',
#  'MepA',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'FadJ',
#  'FadB',
#  'AcpP',
#  'PlsX',
#  'FadJ',
#  'FadB',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'PurN',
#  'PldB',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Adk',
#  'Ndk',
#  'PldB',
#  'Aas',
#  'TesB',
#  'YtjC',
#  'GpmA',
#  'GpmM',
#  'YqaB',
#  'Pgm',
#  'SerA',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'AtpC',
#  'AtpD',
#  'AtpB',
#  'AtpF',
#  'AtpE',
#  'AtpG',
#  'AtpA',
#  'AtpI',
#  'AtpH',
#  'S0001',
#  'MurE',
#  'Gpt',
#  'IlvD',
#  'MsbA',
#  'PurF',
#  'DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'ArgA',
#  'DdlA',
#  'DdlB',
#  'YccX',
#  'PurK',
#  'FabI',
#  'Aas',
#  'AcpP',
#  'SstT',
#  'TesB',
#  'AphA',
#  'SerB',
#  'ZupT',
#  'Deleted',
#  'IlvA',
#  'YchM',
#  'CyoC',
#  'CyoB',
#  'CyoD',
#  'CyoA',
#  'Gmm',
#  'NagB',
#  'PgpB',
#  'BacA',
#  'YbjG',
#  'IspU',
#  'ArgH',
#  'GlmU',
#  'MsbA',
#  'Aas',
#  'IdnK',
#  'GntK',
#  'CitE',
#  'CitF',
#  'CitD',
#  'CitX',
#  'PrpB',
#  'PurE',
#  'PssA',
#  'PgpB',
#  'PgpA',
#  'Aas',
#  'Adk',
#  'Ndk',
#  'YccX',
#  'FabG',
#  'Asd',
#  'MurD',
#  'PurH',
#  'AspC',
#  'PitA',
#  'PitB',
#  'CysI',
#  'CysJ',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'YccX',
#  'PldB',
#  'OppF',
#  'OppB',
#  'OppC',
#  'OppD',
#  'OppA',
#  'FolA',
#  'FolM',
#  'AdiA',
#  'SpeA',
#  'MsbA',
#  'Deleted',
#  'ArgI',
#  'ZitB',
#  'FieF',
#  'Psd',
#  'Fes',
#  'TesB',
#  'SpoT',
#  'RelA',
#  'Gnd',
#  'Aas',
#  'PurB',
#  'DctA',
#  'Aas',
#  'NadD',
#  'NadR',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'CysH',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'GlpK',
#  'ZupT',
#  'CorA',
#  'PldB',
#  'TrpA',
#  'TrpB',
#  'LdcA',
#  'PutA',
#  'PyrE',
#  'FolK',
#  'Ppk',
#  'PldB',
#  'AsnA',
#  'PlsC',
#  'AcpH',
#  'MsbA',
#  'PlsC',
#  'PyrI',
#  'PyrB',
#  'MurF',
#  'S0001',
#  'IlvN',
#  'IlvI',
#  'IlvH',
#  'IlvB',
#  'PgpB',
#  'PgpA',
#  'ZitB',
#  'FieF',
#  'AmpD',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'FhuF',
#  'DeoD',
#  'TktB',
#  'TktA',
#  'ZupT',
#  'SerC',
#  'MgsA',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'NadK',
#  'Pgi',
#  'AmpD',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'ArgE',
#  'Aas',
#  'MsbA',
#  'TdcE',
#  'PflA',
#  'YfiD',
#  'PflB',
#  'PflD',
#  'PflC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'PabA',
#  'PabB',
#  'EntD',
#  'SpeE',
#  'GltA',
#  'CodA',
#  'CodB',
#  'PuuA',
#  'GlgA',
#  'ScpC',
#  'PurC',
#  'MenH',
#  'MenD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GhrB',
#  'ActP',
#  'Lpd',
#  'GlcA',
#  'LldP',
#  'GcvP',
#  'GcvT',
#  'GcvH',
#  'GhrA',
#  'MurG',
#  'HemL',
#  'Aas',
#  'AcpP',
#  'PldB',
#  'Eno',
#  'PurC',
#  'Zwf',
#  'GpsA',
#  'TpiA',
#  'TktB',
#  'TktA',
#  'YccX',
#  'NadE',
#  'Aas',
#  'ArgB',
#  'CysM',
#  'CysK',
#  'CsdA',
#  'SelA',
#  'GldA',
#  'S0001',
#  'AmtB',
#  'CdsA',
#  'EamA',
#  'EamB',
#  'ThrC',
#  'AmpD',
#  'PuuA',
#  'GlnA',
#  'Tmk',
#  'ThiL',
#  'GhrB',
#  'GhrA',
#  'Aas',
#  'AcpP',
#  'FldB',
#  'FldA',
#  'YdbK',
#  'FabI',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'PgpB',
#  'PgpA',
#  'Cdh',
#  'Udk',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'XdhA',
#  'XdhB',
#  'XdhC',
#  'GapA',
#  'GldA',
#  'Adk',
#  'Ndk',
#  'DeoD',
#  'MurA',
#  'Tmk',
#  'Adk',
#  'Ndk',
#  'FhuF',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'TrkA',
#  'Kch',
#  'SapD',
#  'TrkH',
#  'Kup',
#  'TrkG',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'YccX',
#  'Deleted',
#  'DeoD',
#  'MsbA',
#  'Sad',
#  'GabD',
#  'Deleted',
#  'MltC',
#  'EmtA',
#  'MltB',
#  'Slt',
#  'MltA',
#  'AceB',
#  'GlcB',
#  'FabI',
#  'PyrF',
#  'ZupT',
#  'FabI',
#  'Aas',
#  'AcpP',
#  'TesB',
#  'FabI',
#  'Fes',
#  'LdcA',
#  'FolD',
#  'NagZ',
#  'FtsI',
#  'MrcB',
#  'MrcA',
#  'MrdA',
#  'GlpT',
#  'Dcd',
#  'GdhA',
#  'FabI',
#  'LdcA',
#  'AdiC',
#  'YccX',
#  'FhuF',
#  'PgpB',
#  'PgpA',
#  'Cdh',
#  'ArgE',
#  'KatE',
#  'KatG',
#  'Maa',
#  'MsbA',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'Psd',
#  'Dld',
#  'LdhA',
#  'GuaC',
#  'CorA',
#  'Adk',
#  'Adk',
#  'Ndk',
#  'PurU',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'FabI',
#  'Aas',
#  'ArgC',
#  'IlvC',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'RihC',
#  'RihA',
#  'RihB',
#  'ThrA',
#  'MetL',
#  'Cmk',
#  'MsbA',
#  'PurH',
#  'GalP',
#  'GrxB',
#  'CysH',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'ZupT',
#  'PldB',
#  'MpaA',
#  'Mdh',
#  'Mqo',
#  'TesB',
#  'IspH',
#  'PpsA',
#  'Prs',
#  'LeuA',
#  'Udp',
#  'MaeB',
#  'Deleted',
#  'Rpe',
#  'PgpB',
#  'PgpA',
#  'Icd',
#  'PurD',
#  'FabI',
#  'PldB',
#  'FrlA',
#  'LysP',
#  'GsiA',
#  'GsiB',
#  'GsiC',
#  'GsiD',
#  'FabI',
#  'TesB',
#  'ThyA',
#  'PyrG',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'HemA',
#  'AphA',
#  'SurE',
#  'UshA',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'PldB',
#  'PldB',
#  'Deleted',
#  'DeoD',
#  'Cdh',
#  'ZitB',
#  'FieF',
#  'DeoD',
#  'DeoA',
#  'AcnA',
#  'AcnB',
#  'GlmS',
#  'TesB',
#  'FocB',
#  'FocA',
#  'FabB',
#  'Cdh',
#  'GlpQ',
#  'PutA',
#  'AstC',
#  'ArgD',
#  'CysN',
#  'CysD',
#  'AraE',
#  'YdeA',
#  'Deleted',
#  'MltC',
#  'EmtA',
#  'MltB',
#  'Slt',
#  'MltA',
#  'Cdh',
#  'GlmU',
#  'Kbl',
#  'FabI',
#  'ArgG',
#  'RpiB',
#  'RpiA',
#  'Cmk',
#  'PyrH',
#  'Aas',
#  'AmpG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ThrB',
#  'Aas',
#  'Aas',
#  'PyrC',
#  'AcnA',
#  'AcnB',
#  'Aas',
#  'AcpP',
#  'MetC',
#  'TnaA',
#  'IscS',
#  'SufS',
#  'SufE',
#  'ThiD',
#  'PldB',
#  'YahI',
#  'YbcF',
#  'YqeA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'FumB',
#  'FumC',
#  'FumA',
#  'DcuC',
#  'Cdh',
#  'PgpB',
#  'PgpA',
#  'MrcB',
#  'MrcA',
#  'PbpC',
#  'MurJ',
#  'Aas',
#  'Aas',
#  'AcpP',
#  'PldB',
#  'CysE',
#  'PssA',
#  'Deleted',
#  'GadB',
#  'FadE',
#  'PlsY',
#  'ZitB',
#  'FieF',
#  'PntA',
#  'PntB',
#  'PurL',
#  'Gmk',
#  'FabI',
#  'MurC',
#  'PldB',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'CycA',
#  'CysQ',
#  'Alr',
#  'DadX',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'GlmM',
#  'PldB',
#  'ProC',
#  'Ppc',
#  'Dfp',
#  'Pck',
#  'ScpC']

# %%
Ushaped_gene_names = list( dict.fromkeys(Ushaped_gene_names) ) #remove duplicates in the list. I think that you convert it to dictionary and back to list (not sure)
one_gene_names = list( dict.fromkeys(one_gene_names) )
flat_gene_names = list( dict.fromkeys(flat_gene_names) )
saturated_gene_names = list( dict.fromkeys(saturated_gene_names) )
monotonically_increasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_increasingANDstable_reactions_gene_names) )
monotonically_increasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_increasing_only_reactions_gene_names) )
monotonically_decreasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_decreasingANDstable_reactions_gene_names) )
monotonically_decreasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_decreasing_only_reactions_gene_names) )
increasingANDdecreasingANDstable_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasingANDstable_reactions_gene_names) )
increasingANDdecreasing_only_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasing_only_reactions_gene_names) )

d1= pd.DataFrame(Ushaped_gene_names, columns= ["Gene names for Ushaped reactions"])
d2= pd.DataFrame(one_gene_names, columns= ["Gene names for reactions with one feasible value"])
d3= pd.DataFrame(flat_gene_names, columns= ["Gene names for flat reactions"])
d4= pd.DataFrame(saturated_gene_names, columns= ["Gene names for saturating reactions"])
d5= pd.DataFrame(monotonically_increasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and stable reactions"])
d6= pd.DataFrame(monotonically_increasing_only_reactions_gene_names, columns= ["Gene names for increasing only reactions"])
d7= pd.DataFrame(monotonically_decreasingANDstable_reactions_gene_names, columns= ["Gene names for decreasing and stable reactions"])
d8= pd.DataFrame(monotonically_decreasing_only_reactions_gene_names, columns= ["Gene names for decreasing only reactions"])
d9= pd.DataFrame(increasingANDdecreasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and decreasing and stable reactions"])
d10= pd.DataFrame(increasingANDdecreasing_only_reactions_gene_names, columns= ["Gene names for increasing and decreasing only reactions"])

csv_Ushaped_gene_names = d1.to_csv('Ushaped_gene_names lactose.csv', index = True)
csv_one_gene_names = d2.to_csv('one_gene_names lactose.csv', index = True) 
csv_flat_gene_names = d3.to_csv('flat_gene_names lactose.csv', index = True)
csv_saturated_gene_names = d4.to_csv('saturated_gene_names lactose.csv', index = True)
csv_monotonically_increasingANDstable_reactions_gene_names = d5.to_csv('monotonically_increasingANDstable_reactions_gene_names lactose.csv', index = True)
csv_monotonically_increasing_only_reactions_gene_names = d6.to_csv('monotonically_increasing_only_reactions_gene_names lactose.csv', index = True)
csv_monotonically_decreasingANDstable_reactions_gene_names = d7.to_csv('monotonically_decreasingANDstable_reactions_gene_names lactose.csv', index = True)
csv_monotonically_decreasing_only_reactions_gene_names = d8.to_csv('monotonically_decreasing_only_reactions_gene_names lactose.csv', index = True)
csv_increasingANDdecreasingANDstable_reactions_gene_names = d9.to_csv('increasingANDdecreasingANDstable_reactions_gene_names lactose.csv', index = True)
csv_increasingANDdecreasing_only_reactions_gene_names = d10.to_csv('increasingANDdecreasing_only_reactions_gene_names lactose.csv', index = True)
